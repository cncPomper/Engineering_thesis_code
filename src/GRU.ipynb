# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

import random 

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,GRU,SimpleRNN, RNN, Input, Bidirectional
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from sklearn.model_selection import GroupKFold

from tensorflow.keras.optimizers.schedules import ExponentialDecay

from sklearn.metrics import mean_squared_error as mse

from src.utils import *
# Out:
# C:\ML\kaggle\kaggle_competition\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class CFG:
    data_path = "../data"
    img_dim1 = 20
    img_dim2 = 10
    nepochs = 6
    seed = 42
    EPOCH = 300
    bsize = 16
    BATCH_SIZE = 1024


# adjust the parameters for displayed figures    
plt.rcParams.update({'figure.figsize': (CFG.img_dim1,CFG.img_dim2)})   


def seed_everything(seed: int = 42) -> None:
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    
seed_everything(CFG.seed)

# %%
spy_ohlc_df = pd.read_csv(CFG.data_path + '/' + 'spy_ohlc_df.csv')
dow_jones_ohlc_df = pd.read_csv(CFG.data_path + '/' + 'dow_jones_ohlc_df.csv')
nasdaq_ohlc_df = pd.read_csv(CFG.data_path + '/' + 'nasdaq_ohlc_df.csv')

# %%
df = nasdaq_ohlc_df[['Date', 'Close']].copy()
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.head()

# %%
scaler = MinMaxScaler()
df = scaler.fit_transform(df)

# %%
look_back = 50
look_ahead = 10

xdat, ydat = create_dataset(df, look_back = look_back, look_ahead = look_ahead)

xtrain, ytrain, xvalid, yvalid = prepare_split(xdat, ydat, cutoff = 5000, timesteps= look_back)

# %%
early_stop = EarlyStopping(monitor = 'val_loss', min_delta = 0.001, 
                           patience = 5, mode = 'min', verbose = 1,
                           restore_best_weights = True)

# %%
def create_model4(out_dim):
    
    model=Sequential()
    model.add(GRU(10,input_shape= [None,1], return_sequences = True))
    model.add(GRU(10,input_shape= [None,1]))
    model.add(Dense(out_dim))
    
    model.compile(loss='mean_squared_error',optimizer='adam')
    return model
    
model4 = create_model4(out_dim = look_ahead)
model4.summary()

# %%
model4.fit(xtrain, 
           ytrain, 
           validation_data=(xvalid, yvalid), 
           epochs = CFG.nepochs, 
           batch_size = CFG.bsize, 
           callbacks=[early_stop])

y_pred4 = model4.predict(xvalid)
y_pred4 = scaler.inverse_transform(y_pred4)

# %%
print('RMSE: ' + str(my_rmse(y_pred4, scaler.inverse_transform(yvalid))))

# %%
plt.plot(scaler.inverse_transform(yvalid), label = 'real')
plt.plot(y_pred4, label = 'predicted')
plt.ylabel('')
plt.legend()
plt.show()

# %%
import yfinance as yf
from yahooquery import Ticker
from yahooquery import Screener

from tensorflow.keras.layers import Dense, LSTM,GRU,SimpleRNN, RNN, Input, Bidirectional, Dropout

# %%
class CFG:
    data_path = "../data"
    img_dim1 = 20
    img_dim2 = 10
    seed = 42
   

# adjust the parameters for displayed figures    
plt.rcParams.update({'figure.figsize': (CFG.img_dim1,CFG.img_dim2)})   


def seed_everything(seed: int = 42) -> None:
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    
seed_everything(CFG.seed)

# %%
gru_predictions_n_errors = pd.DataFrame(
                                        data=None,
                                        index=None,
                                        columns=['1_day', '5_days', '10_days', '1_month', '2_months', '6_months', '1_year']
                                        )

gru_predictions_n_errors['Dataset'] = ['IXIC', 'IXIC', 'IXIC', 'DJI', 'DJI', 'DJI', 'SPX', 'SPX', 'SPX']
gru_predictions_n_errors['Metric'] = ['RMSE', 'MAE', 'MAPE', 'RMSE', 'MAE', 'MAPE', 'RMSE', 'MAE', 'MAPE']

gru_predictions_n_errors.set_index(['Dataset', 'Metric'], inplace=True)

# %%
nq = yf.download(tickers = "^IXIC",  
                    start='2017-01-01', 
                    end='2023-01-01')

dji = yf.download(tickers = "^DJI",  
                    start='2017-01-01', 
                    end='2023-01-01')

spx = yf.download(tickers = "^SPX",  
                    start='2017-01-01', 
                    end='2023-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
merged_df_dict = {
                  'Date': np.array(nq.index), 
                  'IXIC': np.array(nq.Close.values), 
                  'SPX': np.array(spx.Close.values), 
                  'DJI': np.array(dji.Close.values)
                  }

merged_df_index = nq.index

merged_df = pd.DataFrame(data=merged_df_dict, index=merged_df_index, columns=['Date', 'IXIC', 'SPX', 'DJI'])

# %%
def create_gru_for_ts(output_dim=1):

  model=Sequential()
  model.add(GRU(64, return_sequences = True, input_shape= [None,1]))
  model.add(Dropout(0.2))
  model.add(GRU(128, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(GRU(64, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(GRU(32))
  model.add(Dense(output_dim))
    
  model.compile(loss='mean_squared_error',optimizer='adam')
  return model

# %%
early_stop = EarlyStopping(
                          monitor = 'val_loss', 
                          min_delta = 0.001, 
                          patience = 5, 
                          mode = 'min', 
                          verbose = 1,
                          restore_best_weights = True
                          )

# %%
def gru_pipe(lookback_horizon, save_dir, model_str, gru_predictions_n_errors):

        for dataset in set(gru_predictions_n_errors.index.get_level_values(0)):

                df = merged_df[['Date', dataset]].copy()
                df['Date'] = pd.to_datetime(df['Date'])
                df.set_index('Date', inplace=True)

                scaler = MinMaxScaler()
                df = scaler.fit_transform(df)
        
                for pred_horizon, horizon_string in [[1, '1_day'], [5, '5_days'], [10, '10_days'], [30, '1_month']]:

                        look_back = lookback_horizon
                        look_ahead = pred_horizon

                        xdat, ydat = create_dataset(
                                                df,
                                                look_back = look_back,
                                                look_ahead = look_ahead
                                                )

                        # [batch size, time steps, dimensionality]
                        xtrain, ytrain, xvalid, yvalid = prepare_split(
                                                                xdat,
                                                                ydat,
                                                                cutoff = int(len(xdat) * 0.8),
                                                                timesteps = look_back
                                                                )
                        print(xtrain.shape)
                        model = create_gru_for_ts(look_ahead)

                        model.fit(
                                xtrain, 
                                ytrain, 
                                validation_data = (xvalid, yvalid), 
                                epochs = 20, 
                                batch_size = 32,
                                callbacks=[early_stop]
                                )

                        y_pred = model.predict(xvalid)
                        
                        y_pred = scaler.inverse_transform(y_pred)
                        yvalid = scaler.inverse_transform(yvalid)
                        # if pred_horizon == 1:
                        #         plt.plot(yvalid, label="True")
                        #         plt.plot(y_pred, label="Forecast")
                        # else:

                                # plt.plot([item[0] for item in yvalid], label="True")
                        plt.plot([item[0] for item in yvalid], label="True")
                        # plt.plot([item.mean() for item in y_pred], label="Forecast")
                        # plt.plot([item[0] for item in y_pred], label="Forecast")
                        plt.plot([item[0] for item in y_pred], label="Forecast")
                        plt.legend()
                        plt.savefig(
                                f"{CFG.data_path}/{save_dir}/{model_str}/{model_str}_{dataset}_{horizon_string}.jpg", 
                                bbox_inches='tight', dpi=120
                                )
                        plt.clf()

                        gru_predictions_n_errors = assign_values(gru_predictions_n_errors,
                                                                        dataset,
                                                                        y_pred,
                                                                        yvalid,
                                                                        horizon_string)

        gru_predictions_n_errors.to_csv(f"{CFG.data_path}/{save_dir}/{model_str}/{model_str}_{save_dir}_window_errors.csv")
# y_pred5 = model5.predict(xvalid)
# y_pred5 = scaler.inverse_transform(y_pred5)

# %%
gru_pipe(20, '20d', 'gru_new', gru_predictions_n_errors)
# Out:
# (1191, 20, 1)
# Epoch 1/20
# 38/38 [==============================] - 17s 99ms/step - loss: 0.0149 - val_loss: 0.0016
# Epoch 2/20
# 38/38 [==============================] - 3s 66ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 3/20
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 4/20
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 5/20
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 6/20
# 37/38 [============================>.] - ETA: 0s - loss: 9.9929e-04Restoring model weights from the end of the best epoch: 1.
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 6: early stopping
# 10/10 [==============================] - 1s 13ms/step
# (1188, 20, 1)
# Epoch 1/20
# 38/38 [==============================] - 27s 156ms/step - loss: 0.0243 - val_loss: 0.0047
# Epoch 2/20
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0022 - val_loss: 0.0041
# Epoch 3/20
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 4/20
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 5/20
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 6/20
# 38/38 [==============================] - 3s 79ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 7/20
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 8/20
# 38/38 [==============================] - ETA: 0s - loss: 0.0013Restoring model weights from the end of the best epoch: 3.
# 38/38 [==============================] - 4s 112ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 8: early stopping
# 10/10 [==============================] - 10s 19ms/step
# (1184, 20, 1)
# Epoch 1/20
# 37/37 [==============================] - 12s 123ms/step - loss: 0.0296 - val_loss: 0.0069
# Epoch 2/20
# 37/37 [==============================] - 2s 58ms/step - loss: 0.0026 - val_loss: 0.0052
# Epoch 3/20
# 37/37 [==============================] - 2s 64ms/step - loss: 0.0019 - val_loss: 0.0046
# Epoch 4/20
# 37/37 [==============================] - 2s 61ms/step - loss: 0.0017 - val_loss: 0.0050
# Epoch 5/20
# 37/37 [==============================] - 2s 59ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 6/20
# 37/37 [==============================] - 3s 72ms/step - loss: 0.0015 - val_loss: 0.0049
# Epoch 7/20
# 37/37 [==============================] - 2s 67ms/step - loss: 0.0013 - val_loss: 0.0051
# Epoch 8/20
# 37/37 [==============================] - 3s 68ms/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 9/20
# 37/37 [==============================] - 2s 67ms/step - loss: 0.0013 - val_loss: 0.0072
# Epoch 10/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0015Restoring model weights from the end of the best epoch: 5.
# 37/37 [==============================] - 3s 72ms/step - loss: 0.0015 - val_loss: 0.0042
# Epoch 10: early stopping
# 10/10 [==============================] - 5s 23ms/step
# (1168, 20, 1)
# Epoch 1/20
# 37/37 [==============================] - 22s 149ms/step - loss: 0.0518 - val_loss: 0.0176
# Epoch 2/20
# 37/37 [==============================] - 3s 91ms/step - loss: 0.0047 - val_loss: 0.0149
# Epoch 3/20
# 37/37 [==============================] - 4s 113ms/step - loss: 0.0030 - val_loss: 0.0109
# Epoch 4/20
# 37/37 [==============================] - 4s 95ms/step - loss: 0.0029 - val_loss: 0.0107
# Epoch 5/20
# 37/37 [==============================] - 3s 88ms/step - loss: 0.0025 - val_loss: 0.0133
# Epoch 6/20
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0025 - val_loss: 0.0120
# Epoch 7/20
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0026 - val_loss: 0.0105
# Epoch 8/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0023Restoring model weights from the end of the best epoch: 3.
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0023 - val_loss: 0.0128
# Epoch 8: early stopping
# 10/10 [==============================] - 4s 31ms/step
# (1191, 20, 1)
# Epoch 1/20
# 38/38 [==============================] - 23s 158ms/step - loss: 0.0248 - val_loss: 0.0034
# Epoch 2/20
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 3/20
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 4/20
# 38/38 [==============================] - 4s 89ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 5/20
# 38/38 [==============================] - 3s 79ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 6/20
# 38/38 [==============================] - 3s 77ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 7/20
# 37/38 [============================>.] - ETA: 0s - loss: 0.0016Restoring model weights from the end of the best epoch: 2.
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 15ms/step
# (1188, 20, 1)
# Epoch 1/20
# 38/38 [==============================] - 17s 187ms/step - loss: 0.0295 - val_loss: 0.0040
# Epoch 2/20
# 38/38 [==============================] - 5s 132ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 3/20
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 4/20
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0027 - val_loss: 0.0041
# Epoch 5/20
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 6/20
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 7/20
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 8/20
# 38/38 [==============================] - ETA: 0s - loss: 0.0020Restoring model weights from the end of the best epoch: 3.
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 8: early stopping
# 10/10 [==============================] - 3s 15ms/step
# (1184, 20, 1)
# Epoch 1/20
# 37/37 [==============================] - 16s 192ms/step - loss: 0.0373 - val_loss: 0.0113
# Epoch 2/20
# 37/37 [==============================] - 3s 88ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 3/20
# 37/37 [==============================] - 3s 73ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 4/20
# 37/37 [==============================] - 3s 72ms/step - loss: 0.0034 - val_loss: 0.0051
# Epoch 5/20
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0035 - val_loss: 0.0047
# Epoch 6/20
# 37/37 [==============================] - 3s 82ms/step - loss: 0.0038 - val_loss: 0.0065
# Epoch 7/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0031Restoring model weights from the end of the best epoch: 2.
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0031 - val_loss: 0.0048
# Epoch 7: early stopping
# 10/10 [==============================] - 3s 39ms/step
# (1168, 20, 1)
# Epoch 1/20
# 37/37 [==============================] - 16s 173ms/step - loss: 0.0634 - val_loss: 0.0185
# Epoch 2/20
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0088 - val_loss: 0.0094
# Epoch 3/20
# 37/37 [==============================] - 4s 105ms/step - loss: 0.0070 - val_loss: 0.0081
# Epoch 4/20
# 37/37 [==============================] - 4s 98ms/step - loss: 0.0060 - val_loss: 0.0075
# Epoch 5/20
# 37/37 [==============================] - 4s 103ms/step - loss: 0.0058 - val_loss: 0.0087
# Epoch 6/20
# 37/37 [==============================] - 4s 105ms/step - loss: 0.0052 - val_loss: 0.0077
# Epoch 7/20
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0053 - val_loss: 0.0094
# Epoch 8/20
# 36/37 [============================>.] - ETA: 0s - loss: 0.0051Restoring model weights from the end of the best epoch: 3.
# 37/37 [==============================] - 3s 70ms/step - loss: 0.0050 - val_loss: 0.0080
# Epoch 8: early stopping
# 10/10 [==============================] - 2s 18ms/step
# (1191, 20, 1)
# Epoch 1/20
# 38/38 [==============================] - 15s 113ms/step - loss: 0.0098 - val_loss: 0.0020
# Epoch 2/20
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 3/20
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 4/20
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 5/20
# 38/38 [==============================] - 4s 91ms/step - loss: 0.0010 - val_loss: 0.0023
# Epoch 6/20
# 38/38 [==============================] - ETA: 0s - loss: 0.0012Restoring model weights from the end of the best epoch: 1.
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 6: early stopping
# 10/10 [==============================] - 3s 18ms/step
# (1188, 20, 1)
# Epoch 1/20
# 38/38 [==============================] - 19s 102ms/step - loss: 0.0181 - val_loss: 0.0054
# Epoch 2/20
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0021 - val_loss: 0.0034
# Epoch 3/20
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 4/20
# 38/38 [==============================] - 3s 68ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 5/20
# 38/38 [==============================] - 3s 74ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 6/20
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 7/20
# 37/38 [============================>.] - ETA: 0s - loss: 0.0015Restoring model weights from the end of the best epoch: 2.
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 7: early stopping
# 10/10 [==============================] - 1s 15ms/step
# (1184, 20, 1)
# Epoch 1/20
# 37/37 [==============================] - 13s 104ms/step - loss: 0.0246 - val_loss: 0.0071
# Epoch 2/20
# 37/37 [==============================] - 2s 62ms/step - loss: 0.0028 - val_loss: 0.0046
# Epoch 3/20
# 37/37 [==============================] - 3s 70ms/step - loss: 0.0023 - val_loss: 0.0044
# Epoch 4/20
# 37/37 [==============================] - 2s 64ms/step - loss: 0.0021 - val_loss: 0.0079
# Epoch 5/20
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 6/20
# 37/37 [==============================] - 4s 99ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 7/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0017Restoring model weights from the end of the best epoch: 2.
# 37/37 [==============================] - 3s 70ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 19ms/step
# (1168, 20, 1)
# Epoch 1/20
# 37/37 [==============================] - 12s 109ms/step - loss: 0.0480 - val_loss: 0.0172
# Epoch 2/20
# 37/37 [==============================] - 3s 81ms/step - loss: 0.0056 - val_loss: 0.0101
# Epoch 3/20
# 37/37 [==============================] - 3s 82ms/step - loss: 0.0040 - val_loss: 0.0145
# Epoch 4/20
# 37/37 [==============================] - 3s 80ms/step - loss: 0.0038 - val_loss: 0.0079
# Epoch 5/20
# 37/37 [==============================] - 3s 83ms/step - loss: 0.0034 - val_loss: 0.0088
# Epoch 6/20
# 37/37 [==============================] - 3s 78ms/step - loss: 0.0033 - val_loss: 0.0090
# Epoch 7/20
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0035 - val_loss: 0.0096
# Epoch 8/20
# 37/37 [==============================] - 3s 76ms/step - loss: 0.0033 - val_loss: 0.0086
# Epoch 9/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0031Restoring model weights from the end of the best epoch: 4.
# 37/37 [==============================] - 3s 90ms/step - loss: 0.0031 - val_loss: 0.0103
# Epoch 9: early stopping
# 10/10 [==============================] - 2s 18ms/step

# %%
gru_pipe(50, '50d', 'gru_new', gru_predictions_n_errors)
# Out:
# (1167, 50, 1)
# Epoch 1/20
# 37/37 [==============================] - 19s 213ms/step - loss: 0.0137 - val_loss: 0.0019
# Epoch 2/20
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 3/20
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 4/20
# 37/37 [==============================] - 9s 234ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 5/20
# 37/37 [==============================] - 7s 180ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 6/20
# 37/37 [==============================] - ETA: 0s - loss: 9.2983e-04Restoring model weights from the end of the best epoch: 1.
# 37/37 [==============================] - 6s 153ms/step - loss: 9.2983e-04 - val_loss: 0.0023
# Epoch 6: early stopping
# 10/10 [==============================] - 2s 33ms/step
# (1164, 50, 1)
# Epoch 1/20
# 37/37 [==============================] - 14s 173ms/step - loss: 0.0255 - val_loss: 0.0031
# Epoch 2/20
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 3/20
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0016 - val_loss: 0.0047
# Epoch 4/20
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 5/20
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0015 - val_loss: 0.0033
# Epoch 6/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0013Restoring model weights from the end of the best epoch: 1.
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 6: early stopping
# 10/10 [==============================] - 2s 38ms/step
# (1160, 50, 1)
# Epoch 1/20
# 37/37 [==============================] - 21s 246ms/step - loss: 0.0265 - val_loss: 0.0059
# Epoch 2/20
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0027 - val_loss: 0.0051
# Epoch 3/20
# 37/37 [==============================] - 8s 204ms/step - loss: 0.0019 - val_loss: 0.0044
# Epoch 4/20
# 37/37 [==============================] - 8s 203ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 5/20
# 37/37 [==============================] - 7s 186ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 6/20
# 37/37 [==============================] - 10s 260ms/step - loss: 0.0015 - val_loss: 0.0084
# Epoch 7/20
# 37/37 [==============================] - 8s 213ms/step - loss: 0.0017 - val_loss: 0.0051
# Epoch 8/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0014Restoring model weights from the end of the best epoch: 3.
# 37/37 [==============================] - 7s 177ms/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 8: early stopping
# 10/10 [==============================] - 2s 36ms/step
# (1144, 50, 1)
# Epoch 1/20
# 36/36 [==============================] - 18s 205ms/step - loss: 0.0498 - val_loss: 0.0229
# Epoch 2/20
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0045 - val_loss: 0.0134
# Epoch 3/20
# 36/36 [==============================] - 6s 167ms/step - loss: 0.0030 - val_loss: 0.0106
# Epoch 4/20
# 36/36 [==============================] - 7s 184ms/step - loss: 0.0027 - val_loss: 0.0102
# Epoch 5/20
# 36/36 [==============================] - 6s 176ms/step - loss: 0.0026 - val_loss: 0.0111
# Epoch 6/20
# 36/36 [==============================] - 6s 176ms/step - loss: 0.0024 - val_loss: 0.0099
# Epoch 7/20
# 36/36 [==============================] - 6s 167ms/step - loss: 0.0024 - val_loss: 0.0125
# Epoch 8/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0023Restoring model weights from the end of the best epoch: 3.
# 36/36 [==============================] - 6s 167ms/step - loss: 0.0023 - val_loss: 0.0117
# Epoch 8: early stopping
# 9/9 [==============================] - 2s 42ms/step
# (1167, 50, 1)
# Epoch 1/20
# 37/37 [==============================] - 21s 327ms/step - loss: 0.0167 - val_loss: 0.0017
# Epoch 2/20
# 37/37 [==============================] - 9s 244ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 3/20
# 37/37 [==============================] - 9s 243ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 4/20
# 37/37 [==============================] - 7s 203ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 5/20
# 37/37 [==============================] - 7s 199ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 6/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0016Restoring model weights from the end of the best epoch: 1.
# 37/37 [==============================] - 7s 188ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 6: early stopping
# 10/10 [==============================] - 5s 49ms/step
# (1164, 50, 1)
# Epoch 1/20
# 37/37 [==============================] - 29s 289ms/step - loss: 0.0318 - val_loss: 0.0037
# Epoch 2/20
# 37/37 [==============================] - 7s 185ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 3/20
# 37/37 [==============================] - 7s 188ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 4/20
# 37/37 [==============================] - 9s 249ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 5/20
# 37/37 [==============================] - 7s 200ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 6/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0023Restoring model weights from the end of the best epoch: 1.
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 6: early stopping
# 10/10 [==============================] - 2s 33ms/step
# (1160, 50, 1)
# Epoch 1/20
# 37/37 [==============================] - 19s 208ms/step - loss: 0.0387 - val_loss: 0.0057
# Epoch 2/20
# 37/37 [==============================] - 8s 205ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 3/20
# 37/37 [==============================] - 7s 201ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 4/20
# 37/37 [==============================] - 7s 185ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 5/20
# 37/37 [==============================] - 8s 212ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 6/20
# 37/37 [==============================] - 7s 185ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 7/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0030Restoring model weights from the end of the best epoch: 2.
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0030 - val_loss: 0.0050
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 35ms/step
# (1144, 50, 1)
# Epoch 1/20
# 36/36 [==============================] - 29s 295ms/step - loss: 0.0778 - val_loss: 0.0298
# Epoch 2/20
# 36/36 [==============================] - 6s 176ms/step - loss: 0.0104 - val_loss: 0.0264
# Epoch 3/20
# 36/36 [==============================] - 8s 228ms/step - loss: 0.0082 - val_loss: 0.0081
# Epoch 4/20
# 36/36 [==============================] - 8s 215ms/step - loss: 0.0070 - val_loss: 0.0080
# Epoch 5/20
# 36/36 [==============================] - 7s 190ms/step - loss: 0.0061 - val_loss: 0.0083
# Epoch 6/20
# 36/36 [==============================] - 6s 171ms/step - loss: 0.0055 - val_loss: 0.0100
# Epoch 7/20
# 36/36 [==============================] - 6s 167ms/step - loss: 0.0053 - val_loss: 0.0087
# Epoch 8/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0058Restoring model weights from the end of the best epoch: 3.
# 36/36 [==============================] - 6s 180ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 8: early stopping
# 9/9 [==============================] - 3s 46ms/step
# (1167, 50, 1)
# Epoch 1/20
# 37/37 [==============================] - 23s 248ms/step - loss: 0.0116 - val_loss: 0.0025
# Epoch 2/20
# 37/37 [==============================] - 7s 197ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 3/20
# 37/37 [==============================] - 8s 206ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 4/20
# 37/37 [==============================] - 9s 237ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 5/20
# 37/37 [==============================] - 9s 252ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 6/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0010Restoring model weights from the end of the best epoch: 1.
# 37/37 [==============================] - 10s 270ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 6: early stopping
# 10/10 [==============================] - 4s 52ms/step
# (1164, 50, 1)
# Epoch 1/20
# 37/37 [==============================] - 34s 244ms/step - loss: 0.0245 - val_loss: 0.0051
# Epoch 2/20
# 37/37 [==============================] - 8s 205ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 3/20
# 37/37 [==============================] - 8s 217ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 4/20
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 5/20
# 37/37 [==============================] - 8s 208ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 6/20
# 37/37 [==============================] - 6s 171ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 7/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0014Restoring model weights from the end of the best epoch: 2.
# 37/37 [==============================] - 6s 170ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 7: early stopping
# 10/10 [==============================] - 3s 50ms/step
# (1160, 50, 1)
# Epoch 1/20
# 37/37 [==============================] - 20s 252ms/step - loss: 0.0296 - val_loss: 0.0076
# Epoch 2/20
# 37/37 [==============================] - 8s 213ms/step - loss: 0.0034 - val_loss: 0.0050
# Epoch 3/20
# 37/37 [==============================] - 8s 209ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 4/20
# 37/37 [==============================] - 8s 227ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 5/20
# 37/37 [==============================] - 8s 222ms/step - loss: 0.0022 - val_loss: 0.0065
# Epoch 6/20
# 37/37 [==============================] - 7s 195ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 7/20
# 37/37 [==============================] - ETA: 0s - loss: 0.0018Restoring model weights from the end of the best epoch: 2.
# 37/37 [==============================] - 6s 173ms/step - loss: 0.0018 - val_loss: 0.0053
# Epoch 7: early stopping
# 10/10 [==============================] - 4s 46ms/step
# (1144, 50, 1)
# Epoch 1/20
# 36/36 [==============================] - 23s 332ms/step - loss: 0.0534 - val_loss: 0.0313
# Epoch 2/20
# 36/36 [==============================] - 8s 232ms/step - loss: 0.0065 - val_loss: 0.0096
# Epoch 3/20
# 36/36 [==============================] - 8s 215ms/step - loss: 0.0041 - val_loss: 0.0091
# Epoch 4/20
# 36/36 [==============================] - 9s 264ms/step - loss: 0.0036 - val_loss: 0.0089
# Epoch 5/20
# 36/36 [==============================] - 6s 162ms/step - loss: 0.0036 - val_loss: 0.0166
# Epoch 6/20
# 36/36 [==============================] - 5s 152ms/step - loss: 0.0036 - val_loss: 0.0095
# Epoch 7/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0032Restoring model weights from the end of the best epoch: 2.
# 36/36 [==============================] - 5s 145ms/step - loss: 0.0032 - val_loss: 0.0119
# Epoch 7: early stopping
# 9/9 [==============================] - 2s 44ms/step

# %%
gru_pipe(80, '80d', 'gru_new', gru_predictions_n_errors)
# Out:
# (1143, 80, 1)
# Epoch 1/20
# 36/36 [==============================] - 18s 263ms/step - loss: 0.0162 - val_loss: 0.0026
# Epoch 2/20
# 36/36 [==============================] - 8s 222ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 3/20
# 36/36 [==============================] - 8s 235ms/step - loss: 0.0013 - val_loss: 0.0054
# Epoch 4/20
# 36/36 [==============================] - 9s 245ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 5/20
# 36/36 [==============================] - 8s 224ms/step - loss: 9.5511e-04 - val_loss: 0.0023
# Epoch 6/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0010Restoring model weights from the end of the best epoch: 1.
# 36/36 [==============================] - 8s 221ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 6: early stopping
# 9/9 [==============================] - 2s 58ms/step
# (1140, 80, 1)
# Epoch 1/20
# 36/36 [==============================] - 17s 274ms/step - loss: 0.0310 - val_loss: 0.0049
# Epoch 2/20
# 36/36 [==============================] - 8s 211ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 3/20
# 36/36 [==============================] - 8s 213ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 4/20
# 36/36 [==============================] - 8s 211ms/step - loss: 0.0016 - val_loss: 0.0040
# Epoch 5/20
# 36/36 [==============================] - 8s 213ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 6/20
# 36/36 [==============================] - 8s 212ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 7/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0013Restoring model weights from the end of the best epoch: 2.
# 36/36 [==============================] - 8s 222ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 7: early stopping
# 9/9 [==============================] - 2s 62ms/step
# (1136, 80, 1)
# Epoch 1/20
# 36/36 [==============================] - 31s 389ms/step - loss: 0.0279 - val_loss: 0.0059
# Epoch 2/20
# 36/36 [==============================] - 13s 364ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 3/20
# 36/36 [==============================] - 12s 343ms/step - loss: 0.0019 - val_loss: 0.0047
# Epoch 4/20
# 36/36 [==============================] - 12s 321ms/step - loss: 0.0017 - val_loss: 0.0063
# Epoch 5/20
# 36/36 [==============================] - 11s 294ms/step - loss: 0.0018 - val_loss: 0.0041
# Epoch 6/20
# 36/36 [==============================] - 9s 257ms/step - loss: 0.0015 - val_loss: 0.0069
# Epoch 7/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0015Restoring model weights from the end of the best epoch: 2.
# 36/36 [==============================] - 9s 244ms/step - loss: 0.0015 - val_loss: 0.0108
# Epoch 7: early stopping
# 9/9 [==============================] - 2s 72ms/step
# (1120, 80, 1)
# Epoch 1/20
# 35/35 [==============================] - 16s 306ms/step - loss: 0.0622 - val_loss: 0.0196
# Epoch 2/20
# 35/35 [==============================] - 10s 293ms/step - loss: 0.0055 - val_loss: 0.0150
# Epoch 3/20
# 35/35 [==============================] - 8s 222ms/step - loss: 0.0031 - val_loss: 0.0121
# Epoch 4/20
# 35/35 [==============================] - 7s 206ms/step - loss: 0.0026 - val_loss: 0.0113
# Epoch 5/20
# 35/35 [==============================] - 7s 199ms/step - loss: 0.0025 - val_loss: 0.0169
# Epoch 6/20
# 35/35 [==============================] - 8s 228ms/step - loss: 0.0026 - val_loss: 0.0108
# Epoch 7/20
# 35/35 [==============================] - 9s 243ms/step - loss: 0.0024 - val_loss: 0.0113
# Epoch 8/20
# 35/35 [==============================] - 7s 207ms/step - loss: 0.0024 - val_loss: 0.0180
# Epoch 9/20
# 35/35 [==============================] - 7s 191ms/step - loss: 0.0024 - val_loss: 0.0114
# Epoch 10/20
# 35/35 [==============================] - 7s 212ms/step - loss: 0.0022 - val_loss: 0.0100
# Epoch 11/20
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0022 - val_loss: 0.0097
# Epoch 12/20
# 35/35 [==============================] - 7s 204ms/step - loss: 0.0023 - val_loss: 0.0115
# Epoch 13/20
# 35/35 [==============================] - 7s 199ms/step - loss: 0.0021 - val_loss: 0.0113
# Epoch 14/20
# 35/35 [==============================] - 7s 188ms/step - loss: 0.0022 - val_loss: 0.0130
# Epoch 15/20
# 35/35 [==============================] - 7s 200ms/step - loss: 0.0021 - val_loss: 0.0172
# Epoch 16/20
# 35/35 [==============================] - ETA: 0s - loss: 0.0022Restoring model weights from the end of the best epoch: 11.
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0022 - val_loss: 0.0101
# Epoch 16: early stopping
# 9/9 [==============================] - 5s 66ms/step
# (1143, 80, 1)
# Epoch 1/20
# 36/36 [==============================] - 18s 293ms/step - loss: 0.0214 - val_loss: 0.0038
# Epoch 2/20
# 36/36 [==============================] - 8s 235ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 3/20
# 36/36 [==============================] - 8s 231ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 4/20
# 36/36 [==============================] - 8s 228ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 5/20
# 36/36 [==============================] - 8s 222ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 6/20
# 36/36 [==============================] - 9s 251ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 7/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0017Restoring model weights from the end of the best epoch: 2.
# 36/36 [==============================] - 8s 235ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 7: early stopping
# 9/9 [==============================] - 2s 64ms/step
# (1140, 80, 1)
# Epoch 1/20
# 36/36 [==============================] - 20s 320ms/step - loss: 0.0330 - val_loss: 0.0140
# Epoch 2/20
# 36/36 [==============================] - 8s 221ms/step - loss: 0.0042 - val_loss: 0.0028
# Epoch 3/20
# 36/36 [==============================] - 8s 217ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 4/20
# 36/36 [==============================] - 9s 244ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 5/20
# 36/36 [==============================] - 9s 246ms/step - loss: 0.0028 - val_loss: 0.0036
# Epoch 6/20
# 36/36 [==============================] - 9s 247ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 7/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0025Restoring model weights from the end of the best epoch: 2.
# 36/36 [==============================] - 9s 240ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 7: early stopping
# 9/9 [==============================] - 2s 68ms/step
# (1136, 80, 1)
# Epoch 1/20
# 36/36 [==============================] - 18s 276ms/step - loss: 0.0525 - val_loss: 0.0091
# Epoch 2/20
# 36/36 [==============================] - 8s 229ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 3/20
# 36/36 [==============================] - 9s 238ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 4/20
# 36/36 [==============================] - 9s 241ms/step - loss: 0.0039 - val_loss: 0.0042
# Epoch 5/20
# 36/36 [==============================] - 9s 237ms/step - loss: 0.0033 - val_loss: 0.0052
# Epoch 6/20
# 36/36 [==============================] - 9s 238ms/step - loss: 0.0031 - val_loss: 0.0045
# Epoch 7/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0033Restoring model weights from the end of the best epoch: 2.
# 36/36 [==============================] - 8s 233ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 7: early stopping
# 9/9 [==============================] - 2s 63ms/step
# (1120, 80, 1)
# Epoch 1/20
# 35/35 [==============================] - 15s 252ms/step - loss: 0.0737 - val_loss: 0.0158
# Epoch 2/20
# 35/35 [==============================] - 7s 207ms/step - loss: 0.0088 - val_loss: 0.0084
# Epoch 3/20
# 35/35 [==============================] - 8s 218ms/step - loss: 0.0072 - val_loss: 0.0081
# Epoch 4/20
# 35/35 [==============================] - 7s 212ms/step - loss: 0.0062 - val_loss: 0.0084
# Epoch 5/20
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0060 - val_loss: 0.0083
# Epoch 6/20
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0056 - val_loss: 0.0088
# Epoch 7/20
# 35/35 [==============================] - ETA: 0s - loss: 0.0055Restoring model weights from the end of the best epoch: 2.
# 35/35 [==============================] - 7s 206ms/step - loss: 0.0055 - val_loss: 0.0099
# Epoch 7: early stopping
# 9/9 [==============================] - 2s 67ms/step
# (1143, 80, 1)
# Epoch 1/20
# 36/36 [==============================] - 18s 282ms/step - loss: 0.0159 - val_loss: 0.0055
# Epoch 2/20
# 36/36 [==============================] - 9s 238ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 3/20
# 36/36 [==============================] - 9s 238ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 4/20
# 36/36 [==============================] - 9s 249ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 5/20
# 36/36 [==============================] - 8s 222ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 6/20
# 36/36 [==============================] - 8s 227ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 7/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0012Restoring model weights from the end of the best epoch: 2.
# 36/36 [==============================] - 9s 247ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 7: early stopping
# 9/9 [==============================] - 3s 72ms/step
# (1140, 80, 1)
# Epoch 1/20
# 36/36 [==============================] - 20s 279ms/step - loss: 0.0248 - val_loss: 0.0086
# Epoch 2/20
# 36/36 [==============================] - 9s 246ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 3/20
# 36/36 [==============================] - 9s 259ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 4/20
# 36/36 [==============================] - 8s 235ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 5/20
# 36/36 [==============================] - 8s 232ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 6/20
# 36/36 [==============================] - 8s 232ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 7/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0016Restoring model weights from the end of the best epoch: 2.
# 36/36 [==============================] - 8s 231ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 7: early stopping
# 9/9 [==============================] - 3s 71ms/step
# (1136, 80, 1)
# Epoch 1/20
# 36/36 [==============================] - 18s 265ms/step - loss: 0.0221 - val_loss: 0.0066
# Epoch 2/20
# 36/36 [==============================] - 9s 239ms/step - loss: 0.0028 - val_loss: 0.0054
# Epoch 3/20
# 36/36 [==============================] - 8s 235ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 4/20
# 36/36 [==============================] - 8s 231ms/step - loss: 0.0022 - val_loss: 0.0088
# Epoch 5/20
# 36/36 [==============================] - 8s 234ms/step - loss: 0.0024 - val_loss: 0.0054
# Epoch 6/20
# 36/36 [==============================] - 9s 238ms/step - loss: 0.0020 - val_loss: 0.0055
# Epoch 7/20
# 36/36 [==============================] - 9s 243ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 8/20
# 36/36 [==============================] - ETA: 0s - loss: 0.0019Restoring model weights from the end of the best epoch: 3.
# 36/36 [==============================] - 8s 227ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 8: early stopping
# 9/9 [==============================] - 2s 67ms/step
# (1120, 80, 1)
# Epoch 1/20
# 35/35 [==============================] - 15s 243ms/step - loss: 0.0514 - val_loss: 0.0141
# Epoch 2/20
# 35/35 [==============================] - 7s 194ms/step - loss: 0.0054 - val_loss: 0.0085
# Epoch 3/20
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0045 - val_loss: 0.0090
# Epoch 4/20
# 35/35 [==============================] - 8s 227ms/step - loss: 0.0042 - val_loss: 0.0140
# Epoch 5/20
# 35/35 [==============================] - 8s 217ms/step - loss: 0.0036 - val_loss: 0.0176
# Epoch 6/20
# 35/35 [==============================] - 10s 285ms/step - loss: 0.0036 - val_loss: 0.0107
# Epoch 7/20
# 35/35 [==============================] - ETA: 0s - loss: 0.0034Restoring model weights from the end of the best epoch: 2.
# 35/35 [==============================] - 10s 276ms/step - loss: 0.0034 - val_loss: 0.0109
# Epoch 7: early stopping
# 9/9 [==============================] - 4s 89ms/step
