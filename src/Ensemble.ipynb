# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

import yfinance as yf
from yahooquery import Ticker

from sklearn.svm import SVR
from sklearn.svm import LinearSVR
from sklearn.model_selection import train_test_split

# %matplotlib inline

from utils import *

import tensorflow as tf

from tensorflow.keras.layers import Dropout, Dense, Flatten, Conv1D, MaxPool1D, LSTM, GRU

from sklearn.metrics import mean_squared_error as mse

import xgboost as xgb
from tensorflow.keras.models import Sequential

from sklearn.preprocessing import MinMaxScaler, RobustScaler

from tensorflow.keras.callbacks import EarlyStopping

# %%
class CFG:
    data_path = "../data"
    img_dim1 = 20
    img_dim2 = 10
    seed = 42
   

# adjust the parameters for displayed figures    
plt.rcParams.update({'figure.figsize': (CFG.img_dim1,CFG.img_dim2)})   


def seed_everything(seed: int = 42) -> None:
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    
seed_everything(CFG.seed)

# %%
ensemble_predictions_n_errors = pd.DataFrame(
                                        data=None,
                                        index=None,
                                        columns=['1_day', '5_days', '10_days', '1_month', '2_months', '6_months', '1_year']
                                        )

ensemble_predictions_n_errors['Dataset'] = ['IXIC', 'IXIC', 'IXIC', 'DJI', 'DJI', 'DJI', 'SPX', 'SPX', 'SPX']
ensemble_predictions_n_errors['Metric'] = ['RMSE', 'MAE', 'MAPE', 'RMSE', 'MAE', 'MAPE', 'RMSE', 'MAE', 'MAPE']

ensemble_predictions_n_errors.set_index(['Dataset', 'Metric'], inplace=True)

# %%
START_DATE = '2017-01-01'
END_DATE = '2023-01-01'

nq = yf.download(tickers = "^IXIC",  
                    start=START_DATE, 
                    end=END_DATE)

dji = yf.download(tickers = "^DJI",  
                    start=START_DATE, 
                    end=END_DATE)

spx = yf.download(tickers = "^SPX",  
                    start=START_DATE, 
                    end=END_DATE)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
merged_df_dict = {
                  'Date': np.array(nq.index), 
                  'IXIC': np.array(nq.Close.values), 
                  'SPX': np.array(spx.Close.values), 
                  'DJI': np.array(dji.Close.values)
                  }

merged_df_index = nq.index

merged_df = pd.DataFrame(data=merged_df_dict, index=merged_df_index, columns=['Date', 'IXIC', 'SPX', 'DJI'])

# %%
early_stop = EarlyStopping(monitor = 'val_loss', min_delta = 0.001, 
                           patience = 5, mode = 'min', verbose = 1,
                           restore_best_weights = True)

# %%
def create_lstm(out_dim):    
    
    model=Sequential()
    model.add(LSTM(64, return_sequences = True, input_shape= [None,1]))
    model.add(Dropout(0.2))
    model.add(LSTM(128, return_sequences = True))
    model.add(Dropout(0.2))
    model.add(LSTM(64, return_sequences = True))
    model.add(Dropout(0.2))
    model.add(LSTM(32))
    model.add(Dense(out_dim))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

def create_gru(output_dim):

  model=Sequential()
  model.add(GRU(64, return_sequences = True, input_shape= [None,1]))
  model.add(Dropout(0.2))
  model.add(GRU(128, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(GRU(64, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(GRU(32))
  model.add(Dense(output_dim))
    
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

def create_cnn(input_size=50, output_dim=1):
  model = Sequential([
    Conv1D(filters=128, kernel_size=2, activation='relu', input_shape=(input_size, 1)),
    Conv1D(filters=64, kernel_size=2, activation='relu'),
    MaxPool1D(pool_size=4),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(output_dim),
  ])
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

def create_xgb():
  model = xgb.XGBRegressor(
          n_estimators=1000,
          eta=0.05
          )

  return model

def make_models(input_size, output_dim):
  xgb = create_xgb()
  lstm = create_lstm(output_dim)
  gru = create_gru(output_dim)
  cnn = create_cnn(input_size, output_dim)

  return xgb, lstm, gru, cnn

# %%
def ensemble_pipe(lookback_horizon, save_dir, model_str):

  prediction_dict = {}
  scalers_dict = {}
  for dataset in ['IXIC', 'DJI', 'SPX']:

    df = merged_df[['Date', dataset]].copy()
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)

    scaler = MinMaxScaler()
    df = scaler.fit_transform(df)
    
    # 
    for pred_horizon, horizon_string in [[1, '1_day'], [5, '5_days'], [10, '10_days'], [30, '1_month']]:
      
      look_back = lookback_horizon
      look_ahead = pred_horizon

      xdat, ydat = create_dataset(
                                  df,
                                  look_back = look_back,
                                  look_ahead = look_ahead
                                  )

      # [batch size, time steps, dimensionality]
      xtrain, ytrain, xvalid, yvalid = prepare_split(
                                                    xdat,
                                                    ydat,
                                                    cutoff = int(len(xdat) * 0.8),
                                                    timesteps = look_back
                                                    )

      
      
      #####################################################################
      ############################# LSTM ##################################
      lstm = create_lstm(look_ahead)

      lstm.fit(
              xtrain, 
              ytrain, 
              validation_data = (xvalid, yvalid), 
              epochs = 20, 
              batch_size = 32,
              callbacks=[early_stop],
              verbose=False
              )

      y_pred = lstm.predict(xvalid)
      # y_pred = scaler.inverse_transform(y_pred)

      prediction_dict.update({f"{dataset}_lstm_{horizon_string}": np.array(y_pred)})

      print(f"{dataset}_lstm_{horizon_string} DONE")
      ############################# LSTM ##################################
      #####################################################################    

      #####################################################################
      ############################# GRU ###################################
      gru = create_gru(look_ahead)

      gru.fit(
                xtrain, 
                ytrain, 
                validation_data = (xvalid, yvalid), 
                epochs = 20, 
                batch_size = 32,
                callbacks=[early_stop],
                verbose=False
                )

      y_pred = gru.predict(xvalid)
      # y_pred = scaler.inverse_transform(y_pred)

      prediction_dict.update({f"{dataset}_gru_{horizon_string}": np.array(y_pred)})
      print(f"{dataset}_gru_{horizon_string} DONE")
      ############################# GRU ###################################
      #####################################################################
      xtrain, ytrain, xvalid, yvalid = prepare_split(
                                                    xdat,
                                                    ydat,
                                                    cutoff = int(len(xdat) * 0.8),
                                                    timesteps = look_back
                                                    )
      #####################################################################
      #####################################################################
      # CNN and XGB needs this operations in order to work properly
      # It's a shape thingy 
      xtrain.shape = xtrain.shape[0], xtrain.shape[1]
      xvalid.shape = xvalid.shape[0], xvalid.shape[1]
      #####################################################################
      #####################################################################

      #####################################################################
      ############################# CNN ###################################
      cnn = create_cnn(xtrain.shape[1], look_ahead)
      cnn.compile(optimizer="adam", loss="mse", metrics=["acc"])
      
      cnn.fit(x=xtrain, y=ytrain,
              validation_data=(xvalid, yvalid),
              epochs=20, steps_per_epoch=400, 
              validation_steps=10, verbose=False,
              callbacks=[early_stop])
      
      y_pred = cnn.predict(xvalid)
      # y_pred = scaler.inverse_transform(y_pred)
      
      prediction_dict.update({f"{dataset}_cnn_{horizon_string}": np.array(y_pred)})
      print(f"{dataset}_cnn_{horizon_string} DONE")
      ############################# CNN ###################################
      #####################################################################

      #####################################################################
      ############################# XGB ###################################
      xgb = create_xgb()

      xgb.fit(
        xtrain, ytrain,
        eval_set=[(xtrain, ytrain), (xvalid, yvalid)],
        eval_metric='logloss',
        early_stopping_rounds=50,
        verbose=False
      )
      y_pred = xgb.predict(xvalid)

      if pred_horizon == 1:
        y_pred = y_pred.reshape(-1, 1)
        
      # y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1))

      prediction_dict.update({f"{dataset}_xgb_{horizon_string}": np.array(y_pred)})
      print(f"{dataset}_xgb_{horizon_string} DONE")
      ############################# XGB ###################################
      #####################################################################  
       
      prediction_dict.update({f"{dataset}_valid_data_{horizon_string}": np.array(yvalid)})
      # yvalid = scaler.inverse_transform(yvalid)
      # print(f"valid is {yvalid}")
      # print(prediction_list)

    scalers_dict.update({f"{dataset}_scaler": scaler})
  return prediction_dict, scalers_dict

# %%
# prediction_dict4 = {}
# prediction_dict4, local_scaler4 = ensemble_pipe(20, '20d', 'ensemble')

# %%
prediction_dict_20d = {}
prediction_dict_20d, local_scalers_20d = ensemble_pipe(20, '20d', 'ensemble')
# Out:
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# 10/10 [==============================] - 6s 91ms/step
# IXIC_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 5s 71ms/step
# IXIC_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 10/10 [==============================] - 1s 13ms/step
# IXIC_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# IXIC_xgb_1_day DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 10/10 [==============================] - 13s 120ms/step
# IXIC_lstm_5_days DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 10/10 [==============================] - 5s 39ms/step
# IXIC_gru_5_days DONE
# Restoring model weights from the end of the best epoch: 10.
# Epoch 15: early stopping
# 10/10 [==============================] - 0s 3ms/step
# IXIC_cnn_5_days DONE
# IXIC_xgb_5_days DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 2s 49ms/step
# IXIC_lstm_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 3s 37ms/step
# IXIC_gru_10_days DONE
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# 10/10 [==============================] - 0s 3ms/step
# IXIC_cnn_10_days DONE
# IXIC_xgb_10_days DONE
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# 10/10 [==============================] - 2s 41ms/step
# IXIC_lstm_1_month DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 10/10 [==============================] - 4s 43ms/step
# IXIC_gru_1_month DONE
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# 10/10 [==============================] - 0s 4ms/step
# IXIC_cnn_1_month DONE
# IXIC_xgb_1_month DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 3s 70ms/step
# DJI_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 3s 53ms/step
# DJI_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 10/10 [==============================] - 0s 8ms/step
# DJI_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# DJI_xgb_1_day DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 3s 58ms/step
# DJI_lstm_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 3s 49ms/step
# DJI_gru_5_days DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 0s 4ms/step
# DJI_cnn_5_days DONE
# DJI_xgb_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 3s 68ms/step
# DJI_lstm_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 44ms/step
# DJI_gru_10_days DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 10/10 [==============================] - 0s 4ms/step
# DJI_cnn_10_days DONE
# DJI_xgb_10_days DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 10/10 [==============================] - 3s 79ms/step
# DJI_lstm_1_month DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 10/10 [==============================] - 3s 52ms/step
# DJI_gru_1_month DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 0s 6ms/step
# DJI_cnn_1_month DONE
# DJI_xgb_1_month DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 4s 74ms/step
# SPX_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# 10/10 [==============================] - 3s 47ms/step
# SPX_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 0s 7ms/step
# SPX_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SPX_xgb_1_day DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 5s 113ms/step
# SPX_lstm_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 4s 45ms/step
# SPX_gru_5_days DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 10/10 [==============================] - 0s 4ms/step
# SPX_cnn_5_days DONE
# SPX_xgb_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 4s 53ms/step
# SPX_lstm_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 3s 40ms/step
# SPX_gru_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 0s 3ms/step
# SPX_cnn_10_days DONE
# SPX_xgb_10_days DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 10/10 [==============================] - 4s 64ms/step
# SPX_lstm_1_month DONE
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# 10/10 [==============================] - 2s 32ms/step
# SPX_gru_1_month DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 0s 3ms/step
# SPX_cnn_1_month DONE
# SPX_xgb_1_month DONE

# %%
prediction_dict_50d = {}
prediction_dict_50d, local_scalers_50d = ensemble_pipe(50, '50d', 'ensemble')
# Out:
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 3s 96ms/step
# IXIC_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 10s 86ms/step
# IXIC_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 0s 7ms/step
# IXIC_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# IXIC_xgb_1_day DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 10/10 [==============================] - 3s 95ms/step
# IXIC_lstm_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 76ms/step
# IXIC_gru_5_days DONE
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# 10/10 [==============================] - 0s 5ms/step
# IXIC_cnn_5_days DONE
# IXIC_xgb_5_days DONE
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# 10/10 [==============================] - 4s 131ms/step
# IXIC_lstm_10_days DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 3s 81ms/step
# IXIC_gru_10_days DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 0s 5ms/step
# IXIC_cnn_10_days DONE
# IXIC_xgb_10_days DONE
# Restoring model weights from the end of the best epoch: 12.
# Epoch 17: early stopping
# 9/9 [==============================] - 3s 111ms/step
# IXIC_lstm_1_month DONE
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# 9/9 [==============================] - 2s 78ms/step
# IXIC_gru_1_month DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 9/9 [==============================] - 0s 5ms/step
# IXIC_cnn_1_month DONE
# IXIC_xgb_1_month DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 3s 92ms/step
# DJI_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 69ms/step
# DJI_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 10/10 [==============================] - 0s 5ms/step
# DJI_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# DJI_xgb_1_day DONE
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# 10/10 [==============================] - 3s 107ms/step
# DJI_lstm_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 12s 98ms/step
# DJI_gru_5_days DONE
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# 10/10 [==============================] - 0s 6ms/step
# DJI_cnn_5_days DONE
# DJI_xgb_5_days DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 10/10 [==============================] - 3s 97ms/step
# DJI_lstm_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 75ms/step
# DJI_gru_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 0s 4ms/step
# DJI_cnn_10_days DONE
# DJI_xgb_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 5s 206ms/step
# DJI_lstm_1_month DONE
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# 9/9 [==============================] - 3s 87ms/step
# DJI_gru_1_month DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 0s 5ms/step
# DJI_cnn_1_month DONE
# DJI_xgb_1_month DONE
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# 10/10 [==============================] - 6s 119ms/step
# SPX_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 63ms/step
# SPX_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 0s 4ms/step
# SPX_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SPX_xgb_1_day DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 3s 85ms/step
# SPX_lstm_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 60ms/step
# SPX_gru_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 0s 5ms/step
# SPX_cnn_5_days DONE
# SPX_xgb_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 101ms/step
# SPX_lstm_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 63ms/step
# SPX_gru_10_days DONE
# Restoring model weights from the end of the best epoch: 8.
# Epoch 13: early stopping
# 10/10 [==============================] - 0s 6ms/step
# SPX_cnn_10_days DONE
# SPX_xgb_10_days DONE
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# 9/9 [==============================] - 3s 124ms/step
# SPX_lstm_1_month DONE
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# 9/9 [==============================] - 2s 79ms/step
# SPX_gru_1_month DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 9/9 [==============================] - 0s 6ms/step
# SPX_cnn_1_month DONE
# SPX_xgb_1_month DONE

# %%
prediction_dict_80d = {}
prediction_dict_80d, local_scalers_80d = ensemble_pipe(80, '80d', 'ensemble')
# Out:
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 9/9 [==============================] - 5s 208ms/step
# IXIC_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 5s 134ms/step
# IXIC_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 8.
# Epoch 13: early stopping
# 9/9 [==============================] - 0s 7ms/step
# IXIC_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# IXIC_xgb_1_day DONE
# Restoring model weights from the end of the best epoch: 10.
# Epoch 15: early stopping
# 9/9 [==============================] - 4s 172ms/step
# IXIC_lstm_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 3s 110ms/step
# IXIC_gru_5_days DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 9/9 [==============================] - 0s 7ms/step
# IXIC_cnn_5_days DONE
# IXIC_xgb_5_days DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 9/9 [==============================] - 3s 164ms/step
# IXIC_lstm_10_days DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 9/9 [==============================] - 2s 113ms/step
# IXIC_gru_10_days DONE
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# 9/9 [==============================] - 0s 7ms/step
# IXIC_cnn_10_days DONE
# IXIC_xgb_10_days DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 9/9 [==============================] - 3s 146ms/step
# IXIC_lstm_1_month DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 9/9 [==============================] - 2s 108ms/step
# IXIC_gru_1_month DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 9/9 [==============================] - 0s 5ms/step
# IXIC_cnn_1_month DONE
# IXIC_xgb_1_month DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 9/9 [==============================] - 3s 156ms/step
# DJI_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 9/9 [==============================] - 2s 102ms/step
# DJI_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 9/9 [==============================] - 0s 6ms/step
# DJI_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# DJI_xgb_1_day DONE
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# 9/9 [==============================] - 3s 136ms/step
# DJI_lstm_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 2s 100ms/step
# DJI_gru_5_days DONE
# Restoring model weights from the end of the best epoch: 8.
# Epoch 13: early stopping
# 9/9 [==============================] - 0s 6ms/step
# DJI_cnn_5_days DONE
# DJI_xgb_5_days DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 9/9 [==============================] - 3s 131ms/step
# DJI_lstm_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 2s 100ms/step
# DJI_gru_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 0s 7ms/step
# DJI_cnn_10_days DONE
# DJI_xgb_10_days DONE
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# 9/9 [==============================] - 3s 136ms/step
# DJI_lstm_1_month DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 9/9 [==============================] - 4s 87ms/step
# DJI_gru_1_month DONE
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# 9/9 [==============================] - 0s 22ms/step
# DJI_cnn_1_month DONE
# DJI_xgb_1_month DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 9/9 [==============================] - 3s 125ms/step
# SPX_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 3s 143ms/step
# SPX_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 9/9 [==============================] - 0s 6ms/step
# SPX_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SPX_xgb_1_day DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 9/9 [==============================] - 3s 135ms/step
# SPX_lstm_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 2s 105ms/step
# SPX_gru_5_days DONE
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# 9/9 [==============================] - 0s 6ms/step
# SPX_cnn_5_days DONE
# SPX_xgb_5_days DONE
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# 9/9 [==============================] - 3s 127ms/step
# SPX_lstm_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 3s 123ms/step
# SPX_gru_10_days DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 9/9 [==============================] - 0s 6ms/step
# SPX_cnn_10_days DONE
# SPX_xgb_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 9/9 [==============================] - 3s 126ms/step
# SPX_lstm_1_month DONE
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# 9/9 [==============================] - 2s 95ms/step
# SPX_gru_1_month DONE
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 9/9 [==============================] - 0s 6ms/step
# SPX_cnn_1_month DONE
# SPX_xgb_1_month DONE

# %%
with open(f"{CFG.data_path}/80d/ensemble/prediction_ypred_yvalid.pkl", 'wb') as f:
  pickle.dump(prediction_dict_80d, f)

with open(f"{CFG.data_path}/80d/ensemble/local_scalers.pkl", 'wb') as f:
  pickle.dump(local_scalers_80d, f)

# %%
with open(f"{CFG.data_path}/50d/ensemble/prediction_ypred_yvalid.pkl", 'wb') as f:
  pickle.dump(prediction_dict_50d, f)

with open(f"{CFG.data_path}/50d/ensemble/local_scalers.pkl", 'wb') as f:
  pickle.dump(local_scalers_50d, f)

# %%
pred_foo_20d_scalers = 0

with open(f"{CFG.data_path}/20d/ensemble/local_scalers.pkl", 'rb') as f:
    pred_foo_20d_scalers = pickle.load(f)

# %%
pred_foo_20d_scalers
# Out:
# {'IXIC_scaler': MinMaxScaler(),
#  'DJI_scaler': MinMaxScaler(),
#  'SPX_scaler': MinMaxScaler()}

# %%
pred_foo_20d_scalers = 0

with open(f"{CFG.data_path}/20d/ensemble/local_scalers.pkl", 'rb') as f:
    pred_foo_20d_scalers = pickle.load(f)

pred_foo_20d = 0

with open(f"{CFG.data_path}/20d/ensemble/prediction_ypred_yvalid.pkl", 'rb') as f:
    pred_foo_20d = pickle.load(f)
    
print(pred_foo_20d)
# Out:
# {'IXIC_lstm_1_day': array([[0.84087676],
#        [0.84234184],
#        [0.8454307 ],
#        [0.84893495],
#        [0.85286796],
#        [0.8567325 ],
#        [0.861588  ],
#        [0.86611634],
#        [0.8706661 ],
#        [0.8750862 ],
#        [0.87997806],
#        [0.8853309 ],
#        [0.89087075],
#        [0.8961637 ],
#        [0.900784  ],
#        [0.9051495 ],
#        [0.909094  ],
#        [0.9126666 ],
#        [0.9161351 ],
#        [0.91924804],
#        [0.9225394 ],
#        [0.92533416],
#        [0.9279197 ],
#        [0.9302764 ],
#        [0.93183357],
#        [0.9329977 ],
#        [0.93362385],
#        [0.9337518 ],
#        [0.93309975],
#        [0.93172157],
#        [0.92984885],
#        [0.92762446],
#        [0.925441  ],
#        [0.923756  ],
#        [0.9218056 ],
#        [0.9195131 ],
#        [0.91731125],
#        [0.9149447 ],
#        [0.91282415],
#        [0.9105964 ],
#        [0.9082283 ],
#        [0.90635026],
#        [0.9046571 ],
#        [0.90287995],
#        [0.9021768 ],
#        [0.9010429 ],
#        [0.90092033],
#        [0.9018369 ],
#        [0.9027154 ],
#        [0.90457714],
#        [0.9062412 ],
#        [0.9068562 ],
#        [0.90724945],
#        [0.90810096],
#        [0.9082558 ],
#        [0.9084461 ],
#        [0.90848887],
#        [0.9071415 ],
#        [0.90618074],
#        [0.9045634 ],
#        [0.9026499 ],
#        [0.89904   ],
#        [0.8941866 ],
#        [0.8882154 ],
#        [0.8809067 ],
#        [0.8730533 ],
#        [0.86444515],
#        [0.85523283],
#        [0.8458781 ],
#        [0.83601606],
#        [0.827085  ],
#        [0.82000947],
#        [0.8135068 ],
#        [0.8079975 ],
#        [0.8031344 ],
#        [0.798529  ],
#        [0.7947522 ],
#        [0.7927669 ],
#        [0.79105765],
#        [0.7907664 ],
#        [0.791097  ],
#        [0.79189956],
#        [0.79343563],
#        [0.7941861 ],
#        [0.79500353],
#        [0.7948887 ],
#        [0.7944042 ],
#        [0.79209405],
#        [0.78814805],
#        [0.7838602 ],
#        [0.779477  ],
#        [0.7766235 ],
#        [0.7730263 ],
#        [0.7694281 ],
#        [0.76510406],
#        [0.75984776],
#        [0.75532603],
#        [0.75157   ],
#        [0.74740994],
#        [0.7421242 ],
#        [0.73709124],
#        [0.7336581 ],
#        [0.7313047 ],
#        [0.7302271 ],
#        [0.73097813],
#        [0.7314697 ],
#        [0.7325114 ],
#        [0.73463154],
#        [0.7385601 ],
#        [0.7429536 ],
#        [0.7488331 ],
#        [0.75587255],
#        [0.76442933],
#        [0.7729176 ],
#        [0.77981126],
#        [0.78655195],
#        [0.7932391 ],
#        [0.7994464 ],
#        [0.8033166 ],
#        [0.8046754 ],
#        [0.80448526],
#        [0.80258375],
#        [0.800042  ],
#        [0.79614216],
#        [0.7922325 ],
#        [0.7870793 ],
#        [0.7815675 ],
#        [0.77509344],
#        [0.76747286],
#        [0.76001716],
#        [0.75276715],
#        [0.74500287],
#        [0.7362448 ],
#        [0.7284082 ],
#        [0.7214222 ],
#        [0.71432424],
#        [0.7075356 ],
#        [0.7011801 ],
#        [0.6942965 ],
#        [0.6859339 ],
#        [0.67781055],
#        [0.669183  ],
#        [0.659462  ],
#        [0.65017605],
#        [0.6416662 ],
#        [0.6340488 ],
#        [0.6259177 ],
#        [0.6193076 ],
#        [0.61266464],
#        [0.60510945],
#        [0.5996689 ],
#        [0.59430254],
#        [0.58979344],
#        [0.58530724],
#        [0.5839945 ],
#        [0.58417654],
#        [0.5866653 ],
#        [0.5893432 ],
#        [0.593409  ],
#        [0.59731483],
#        [0.599455  ],
#        [0.6012125 ],
#        [0.6009949 ],
#        [0.6011691 ],
#        [0.5999127 ],
#        [0.59733176],
#        [0.59302855],
#        [0.5886426 ],
#        [0.5832423 ],
#        [0.57693297],
#        [0.56988037],
#        [0.56365705],
#        [0.5583723 ],
#        [0.5528207 ],
#        [0.54892975],
#        [0.5455646 ],
#        [0.54263216],
#        [0.5408174 ],
#        [0.54071647],
#        [0.5422822 ],
#        [0.5455013 ],
#        [0.5484751 ],
#        [0.55047584],
#        [0.55361086],
#        [0.556048  ],
#        [0.5576781 ],
#        [0.5596126 ],
#        [0.56140065],
#        [0.5626058 ],
#        [0.5645839 ],
#        [0.5679647 ],
#        [0.57164323],
#        [0.5760856 ],
#        [0.58059126],
#        [0.58496594],
#        [0.5897766 ],
#        [0.59446675],
#        [0.5998047 ],
#        [0.6064587 ],
#        [0.61371374],
#        [0.6211703 ],
#        [0.628665  ],
#        [0.63562834],
#        [0.6429431 ],
#        [0.6493433 ],
#        [0.65537536],
#        [0.66107774],
#        [0.6673778 ],
#        [0.67343575],
#        [0.67942876],
#        [0.68323565],
#        [0.6859199 ],
#        [0.68717223],
#        [0.6876508 ],
#        [0.68723583],
#        [0.6849394 ],
#        [0.6815976 ],
#        [0.67753685],
#        [0.6726143 ],
#        [0.66731787],
#        [0.66038364],
#        [0.65344477],
#        [0.6458545 ],
#        [0.63840795],
#        [0.63152325],
#        [0.6255703 ],
#        [0.6198817 ],
#        [0.61520976],
#        [0.61154234],
#        [0.60774434],
#        [0.60357416],
#        [0.598495  ],
#        [0.59443974],
#        [0.59007865],
#        [0.58544964],
#        [0.5803685 ],
#        [0.57475644],
#        [0.5690663 ],
#        [0.56328136],
#        [0.55670387],
#        [0.5501931 ],
#        [0.5433662 ],
#        [0.5365986 ],
#        [0.53208137],
#        [0.5273657 ],
#        [0.5231799 ],
#        [0.519205  ],
#        [0.51489604],
#        [0.51095873],
#        [0.50771487],
#        [0.5050068 ],
#        [0.5030172 ],
#        [0.50142443],
#        [0.5001346 ],
#        [0.49872664],
#        [0.49882144],
#        [0.4998475 ],
#        [0.50057197],
#        [0.50069934],
#        [0.50130105],
#        [0.5022168 ],
#        [0.50413644],
#        [0.50584334],
#        [0.5072551 ],
#        [0.5079783 ],
#        [0.5075065 ],
#        [0.507812  ],
#        [0.5071037 ],
#        [0.506541  ],
#        [0.50685066],
#        [0.5079635 ],
#        [0.5089512 ],
#        [0.51025575],
#        [0.51137805],
#        [0.5136726 ],
#        [0.5167814 ],
#        [0.5191207 ],
#        [0.52186775],
#        [0.5248812 ],
#        [0.52888143],
#        [0.53322667],
#        [0.53695816],
#        [0.5401799 ],
#        [0.5429197 ],
#        [0.54599285],
#        [0.546351  ],
#        [0.5458921 ],
#        [0.54568875],
#        [0.54491115],
#        [0.5445317 ],
#        [0.54399323],
#        [0.5430412 ],
#        [0.541914  ],
#        [0.5397732 ],
#        [0.5367838 ],
#        [0.5334877 ],
#        [0.53019834],
#        [0.52652246]], dtype=float32), 'IXIC_gru_1_day': array([[0.8673804 ],
#        [0.8728126 ],
#        [0.87756896],
#        [0.88163394],
#        [0.8857112 ],
#        [0.8901613 ],
#        [0.89516336],
#        [0.9006152 ],
#        [0.9066669 ],
#        [0.9134471 ],
#        [0.92066747],
#        [0.927806  ],
#        [0.9340373 ],
#        [0.9380765 ],
#        [0.93996036],
#        [0.94077814],
#        [0.941272  ],
#        [0.9421663 ],
#        [0.9434569 ],
#        [0.9451618 ],
#        [0.94733876],
#        [0.9491463 ],
#        [0.9498999 ],
#        [0.9497755 ],
#        [0.94796926],
#        [0.9454743 ],
#        [0.9423273 ],
#        [0.93778086],
#        [0.93237   ],
#        [0.92587346],
#        [0.91909844],
#        [0.9143679 ],
#        [0.91285324],
#        [0.91333777],
#        [0.9149723 ],
#        [0.91638786],
#        [0.9163748 ],
#        [0.91587335],
#        [0.91433483],
#        [0.9116436 ],
#        [0.90753484],
#        [0.9035863 ],
#        [0.9013667 ],
#        [0.9016564 ],
#        [0.9048383 ],
#        [0.9099214 ],
#        [0.9156695 ],
#        [0.9210766 ],
#        [0.92528915],
#        [0.9287065 ],
#        [0.9309608 ],
#        [0.93026346],
#        [0.92637354],
#        [0.91974485],
#        [0.9115435 ],
#        [0.9037297 ],
#        [0.8975389 ],
#        [0.8919936 ],
#        [0.88684   ],
#        [0.88084114],
#        [0.87325215],
#        [0.86383563],
#        [0.85201526],
#        [0.83882666],
#        [0.8246069 ],
#        [0.8102377 ],
#        [0.7960851 ],
#        [0.78423625],
#        [0.777339  ],
#        [0.77605605],
#        [0.7794619 ],
#        [0.78390193],
#        [0.7879374 ],
#        [0.790846  ],
#        [0.79316574],
#        [0.7963191 ],
#        [0.79960334],
#        [0.80097866],
#        [0.79984367],
#        [0.79794   ],
#        [0.79642147],
#        [0.79425865],
#        [0.7904482 ],
#        [0.7845173 ],
#        [0.77583885],
#        [0.7666447 ],
#        [0.7594316 ],
#        [0.7552964 ],
#        [0.75323737],
#        [0.75300854],
#        [0.75341237],
#        [0.75290465],
#        [0.74932235],
#        [0.7424313 ],
#        [0.73499835],
#        [0.72845984],
#        [0.722316  ],
#        [0.71537316],
#        [0.70884395],
#        [0.7054006 ],
#        [0.7063682 ],
#        [0.71208906],
#        [0.7210603 ],
#        [0.7323139 ],
#        [0.743855  ],
#        [0.7551666 ],
#        [0.76570255],
#        [0.775634  ],
#        [0.785762  ],
#        [0.7953981 ],
#        [0.80306864],
#        [0.8083704 ],
#        [0.81251836],
#        [0.815134  ],
#        [0.8150538 ],
#        [0.81237346],
#        [0.8073105 ],
#        [0.7996699 ],
#        [0.7900755 ],
#        [0.7806605 ],
#        [0.7717768 ],
#        [0.76355445],
#        [0.7572242 ],
#        [0.7526365 ],
#        [0.74839044],
#        [0.742671  ],
#        [0.7358437 ],
#        [0.7269702 ],
#        [0.71634275],
#        [0.706416  ],
#        [0.69673675],
#        [0.68787754],
#        [0.68045235],
#        [0.676149  ],
#        [0.6728825 ],
#        [0.6686679 ],
#        [0.6611833 ],
#        [0.6508916 ],
#        [0.6379546 ],
#        [0.62355614],
#        [0.61081755],
#        [0.6008445 ],
#        [0.59484994],
#        [0.5905789 ],
#        [0.58640575],
#        [0.58174205],
#        [0.5774207 ],
#        [0.5730288 ],
#        [0.5690897 ],
#        [0.5671129 ],
#        [0.5689084 ],
#        [0.5741093 ],
#        [0.5810219 ],
#        [0.5893211 ],
#        [0.5972343 ],
#        [0.60382295],
#        [0.60924697],
#        [0.61339915],
#        [0.615119  ],
#        [0.6127795 ],
#        [0.6047218 ],
#        [0.5919539 ],
#        [0.57775927],
#        [0.5629599 ],
#        [0.5489435 ],
#        [0.53775704],
#        [0.5300606 ],
#        [0.52616996],
#        [0.52686346],
#        [0.5311055 ],
#        [0.53600097],
#        [0.5398057 ],
#        [0.5414535 ],
#        [0.5413729 ],
#        [0.54102886],
#        [0.5413506 ],
#        [0.5434739 ],
#        [0.54743636],
#        [0.55157226],
#        [0.55440974],
#        [0.55548143],
#        [0.5550701 ],
#        [0.55448115],
#        [0.55408365],
#        [0.5552172 ],
#        [0.5588233 ],
#        [0.56513065],
#        [0.57243353],
#        [0.5791139 ],
#        [0.58357346],
#        [0.5872239 ],
#        [0.5914694 ],
#        [0.5974214 ],
#        [0.6047847 ],
#        [0.6125923 ],
#        [0.62112683],
#        [0.63030064],
#        [0.6392888 ],
#        [0.64730513],
#        [0.6533794 ],
#        [0.65860534],
#        [0.663355  ],
#        [0.66859186],
#        [0.6747408 ],
#        [0.68136275],
#        [0.6872214 ],
#        [0.6917614 ],
#        [0.6940089 ],
#        [0.6927863 ],
#        [0.68843067],
#        [0.6823057 ],
#        [0.67649525],
#        [0.6702931 ],
#        [0.66301036],
#        [0.65441066],
#        [0.64484334],
#        [0.63501066],
#        [0.6251305 ],
#        [0.61533654],
#        [0.6069656 ],
#        [0.6009651 ],
#        [0.59831583],
#        [0.59932345],
#        [0.6008248 ],
#        [0.601302  ],
#        [0.59989405],
#        [0.5964161 ],
#        [0.5918007 ],
#        [0.5865891 ],
#        [0.58055216],
#        [0.5733808 ],
#        [0.5647464 ],
#        [0.5549562 ],
#        [0.54495895],
#        [0.5365056 ],
#        [0.5292128 ],
#        [0.5221227 ],
#        [0.5159252 ],
#        [0.5124821 ],
#        [0.51208115],
#        [0.5137104 ],
#        [0.5146954 ],
#        [0.51345706],
#        [0.50958204],
#        [0.50374055],
#        [0.4978957 ],
#        [0.49198982],
#        [0.48739073],
#        [0.4850646 ],
#        [0.48458943],
#        [0.4849907 ],
#        [0.4865182 ],
#        [0.4894263 ],
#        [0.4943124 ],
#        [0.4999349 ],
#        [0.50452554],
#        [0.5085172 ],
#        [0.5118557 ],
#        [0.514119  ],
#        [0.51387537],
#        [0.5103295 ],
#        [0.5046219 ],
#        [0.49848786],
#        [0.49325463],
#        [0.48843852],
#        [0.48663852],
#        [0.48941237],
#        [0.49562958],
#        [0.50411105],
#        [0.51283157],
#        [0.5203135 ],
#        [0.5259879 ],
#        [0.5294453 ],
#        [0.53146434],
#        [0.533157  ],
#        [0.53479904],
#        [0.5356996 ],
#        [0.5353677 ],
#        [0.5357308 ],
#        [0.5377118 ],
#        [0.5410526 ],
#        [0.5442457 ],
#        [0.5456064 ],
#        [0.5445759 ],
#        [0.5420944 ],
#        [0.53884256],
#        [0.5359169 ],
#        [0.53427964],
#        [0.5337592 ],
#        [0.5325837 ],
#        [0.52965796],
#        [0.52452064],
#        [0.51776695],
#        [0.51100886],
#        [0.50441647],
#        [0.49822587],
#        [0.49215326],
#        [0.48571613]], dtype=float32), 'IXIC_cnn_1_day': array([[0.8505874 ],
#        [0.8568662 ],
#        [0.8604911 ],
#        [0.86297303],
#        [0.867476  ],
#        [0.8724237 ],
#        [0.87770575],
#        [0.8862272 ],
#        [0.8930664 ],
#        [0.89889014],
#        [0.9054369 ],
#        [0.91540617],
#        [0.92406464],
#        [0.92861336],
#        [0.93195635],
#        [0.93651754],
#        [0.9402682 ],
#        [0.941521  ],
#        [0.9371405 ],
#        [0.9410497 ],
#        [0.9450616 ],
#        [0.94625163],
#        [0.94600946],
#        [0.9475669 ],
#        [0.9485631 ],
#        [0.9485621 ],
#        [0.94744986],
#        [0.94186276],
#        [0.93878365],
#        [0.93515706],
#        [0.9317667 ],
#        [0.92868906],
#        [0.9194564 ],
#        [0.9093182 ],
#        [0.9213805 ],
#        [0.9239594 ],
#        [0.9199035 ],
#        [0.9150667 ],
#        [0.9204575 ],
#        [0.91630226],
#        [0.91096866],
#        [0.9033138 ],
#        [0.9055025 ],
#        [0.9039168 ],
#        [0.8990493 ],
#        [0.9063058 ],
#        [0.9146444 ],
#        [0.92013115],
#        [0.91801727],
#        [0.9210531 ],
#        [0.92465943],
#        [0.9255573 ],
#        [0.9238474 ],
#        [0.9253162 ],
#        [0.9277261 ],
#        [0.9286495 ],
#        [0.91609585],
#        [0.8979927 ],
#        [0.893238  ],
#        [0.8933465 ],
#        [0.8878857 ],
#        [0.8806842 ],
#        [0.8764743 ],
#        [0.86655384],
#        [0.8554105 ],
#        [0.8386827 ],
#        [0.8247488 ],
#        [0.8084324 ],
#        [0.7936689 ],
#        [0.7817746 ],
#        [0.7789342 ],
#        [0.7910045 ],
#        [0.793259  ],
#        [0.7875524 ],
#        [0.7866188 ],
#        [0.79081535],
#        [0.78733397],
#        [0.78405225],
#        [0.79241437],
#        [0.797149  ],
#        [0.7972023 ],
#        [0.7975274 ],
#        [0.7886655 ],
#        [0.7843763 ],
#        [0.78212756],
#        [0.7827824 ],
#        [0.77566224],
#        [0.7597666 ],
#        [0.74858826],
#        [0.7548489 ],
#        [0.7524348 ],
#        [0.74595416],
#        [0.7412073 ],
#        [0.7437145 ],
#        [0.7410101 ],
#        [0.73663414],
#        [0.7270439 ],
#        [0.7130995 ],
#        [0.7079444 ],
#        [0.7077723 ],
#        [0.7047559 ],
#        [0.6956523 ],
#        [0.7093112 ],
#        [0.7234852 ],
#        [0.730805  ],
#        [0.7312332 ],
#        [0.7418079 ],
#        [0.7499166 ],
#        [0.7585531 ],
#        [0.7659636 ],
#        [0.78034747],
#        [0.79241943],
#        [0.7965358 ],
#        [0.8006673 ],
#        [0.80503047],
#        [0.803472  ],
#        [0.80276793],
#        [0.80408233],
#        [0.8064831 ],
#        [0.79431754],
#        [0.78098875],
#        [0.77470934],
#        [0.7648422 ],
#        [0.75043803],
#        [0.7449241 ],
#        [0.7427277 ],
#        [0.73811775],
#        [0.73169285],
#        [0.7287589 ],
#        [0.7213898 ],
#        [0.70391804],
#        [0.69201165],
#        [0.6849545 ],
#        [0.6735376 ],
#        [0.66712624],
#        [0.66492516],
#        [0.6636889 ],
#        [0.6580355 ],
#        [0.6539048 ],
#        [0.6516498 ],
#        [0.63310665],
#        [0.6113014 ],
#        [0.5962537 ],
#        [0.59198177],
#        [0.59161395],
#        [0.58433586],
#        [0.57834935],
#        [0.5745001 ],
#        [0.57125443],
#        [0.5527982 ],
#        [0.5441965 ],
#        [0.5463289 ],
#        [0.56372607],
#        [0.5730589 ],
#        [0.5728999 ],
#        [0.576034  ],
#        [0.58468497],
#        [0.5872741 ],
#        [0.58682674],
#        [0.58874243],
#        [0.592691  ],
#        [0.59563625],
#        [0.5962213 ],
#        [0.59069914],
#        [0.5734394 ],
#        [0.5497749 ],
#        [0.53157043],
#        [0.5268188 ],
#        [0.5240447 ],
#        [0.5197881 ],
#        [0.5229169 ],
#        [0.5319082 ],
#        [0.52974576],
#        [0.5257949 ],
#        [0.52649957],
#        [0.5274094 ],
#        [0.51761466],
#        [0.5213588 ],
#        [0.53204083],
#        [0.5411234 ],
#        [0.5378224 ],
#        [0.53871006],
#        [0.5416006 ],
#        [0.5420512 ],
#        [0.5304801 ],
#        [0.53030187],
#        [0.5377527 ],
#        [0.5511895 ],
#        [0.5598443 ],
#        [0.56300014],
#        [0.5650552 ],
#        [0.5689237 ],
#        [0.5713565 ],
#        [0.5729073 ],
#        [0.587321  ],
#        [0.5981495 ],
#        [0.6028823 ],
#        [0.6076171 ],
#        [0.6223346 ],
#        [0.6294689 ],
#        [0.6299952 ],
#        [0.6326518 ],
#        [0.63969666],
#        [0.6466274 ],
#        [0.6530091 ],
#        [0.6622752 ],
#        [0.6696352 ],
#        [0.6721422 ],
#        [0.67469513],
#        [0.677659  ],
#        [0.6774102 ],
#        [0.6738731 ],
#        [0.67072165],
#        [0.66065013],
#        [0.6510361 ],
#        [0.64913696],
#        [0.6468224 ],
#        [0.6399075 ],
#        [0.6214993 ],
#        [0.609152  ],
#        [0.6011424 ],
#        [0.5932048 ],
#        [0.58331704],
#        [0.58682674],
#        [0.59478635],
#        [0.59255344],
#        [0.58778703],
#        [0.58834046],
#        [0.5878106 ],
#        [0.5722135 ],
#        [0.5643973 ],
#        [0.5614453 ],
#        [0.55936533],
#        [0.5532674 ],
#        [0.54501295],
#        [0.53337276],
#        [0.5201777 ],
#        [0.5095935 ],
#        [0.5050032 ],
#        [0.49980265],
#        [0.49602693],
#        [0.5017147 ],
#        [0.50292903],
#        [0.50052303],
#        [0.49802703],
#        [0.5005233 ],
#        [0.49270156],
#        [0.4781856 ],
#        [0.4686924 ],
#        [0.4700268 ],
#        [0.472521  ],
#        [0.4724536 ],
#        [0.46828812],
#        [0.46782234],
#        [0.47322196],
#        [0.48126253],
#        [0.48380405],
#        [0.48382854],
#        [0.4879517 ],
#        [0.4930616 ],
#        [0.49094978],
#        [0.4910154 ],
#        [0.49249193],
#        [0.49366534],
#        [0.4830975 ],
#        [0.47019553],
#        [0.46916747],
#        [0.47180796],
#        [0.48822907],
#        [0.4962414 ],
#        [0.49721172],
#        [0.49894923],
#        [0.5045611 ],
#        [0.507174  ],
#        [0.50735265],
#        [0.5059968 ],
#        [0.50914454],
#        [0.51584905],
#        [0.516341  ],
#        [0.51456213],
#        [0.51389056],
#        [0.52208084],
#        [0.527699  ],
#        [0.5269933 ],
#        [0.52679014],
#        [0.5303297 ],
#        [0.52897364],
#        [0.51894575],
#        [0.5100546 ],
#        [0.51638955],
#        [0.5197567 ],
#        [0.5157006 ],
#        [0.5118382 ],
#        [0.51375026],
#        [0.5072701 ],
#        [0.49171382],
#        [0.480313  ],
#        [0.47755456]], dtype=float32), 'IXIC_xgb_1_day': array([[0.90330386],
#        [0.91724217],
#        [0.90784895],
#        [0.910085  ],
#        [0.92063516],
#        [0.9163015 ],
#        [0.9187424 ],
#        [0.9102494 ],
#        [0.9168737 ],
#        [0.9220447 ],
#        [0.91781664],
#        [0.91487765],
#        [0.91766083],
#        [0.91206074],
#        [0.8951069 ],
#        [0.89287806],
#        [0.8951069 ],
#        [0.8927498 ],
#        [0.8794012 ],
#        [0.8935251 ],
#        [0.87827384],
#        [0.87827384],
#        [0.8772322 ],
#        [0.87642   ],
#        [0.87642   ],
#        [0.87642   ],
#        [0.87642   ],
#        [0.87616754],
#        [0.87642   ],
#        [0.852496  ],
#        [0.8680539 ],
#        [0.8757285 ],
#        [0.876199  ],
#        [0.87232757],
#        [0.87608916],
#        [0.87628776],
#        [0.8696424 ],
#        [0.879581  ],
#        [0.8687761 ],
#        [0.8719064 ],
#        [0.849458  ],
#        [0.87521815],
#        [0.87671894],
#        [0.8757384 ],
#        [0.8718172 ],
#        [0.87753594],
#        [0.8816432 ],
#        [0.87908924],
#        [0.9171705 ],
#        [0.8806406 ],
#        [0.87976205],
#        [0.85202134],
#        [0.8527092 ],
#        [0.8479837 ],
#        [0.8604965 ],
#        [0.8669431 ],
#        [0.86609685],
#        [0.87358415],
#        [0.8698102 ],
#        [0.8591584 ],
#        [0.8299036 ],
#        [0.8140682 ],
#        [0.7913674 ],
#        [0.78603953],
#        [0.7452821 ],
#        [0.74383855],
#        [0.7158014 ],
#        [0.7619019 ],
#        [0.80372626],
#        [0.8271684 ],
#        [0.8438892 ],
#        [0.8120146 ],
#        [0.8169782 ],
#        [0.81449354],
#        [0.8207807 ],
#        [0.84641063],
#        [0.82550526],
#        [0.8113937 ],
#        [0.80699044],
#        [0.8036595 ],
#        [0.8151252 ],
#        [0.77222836],
#        [0.7607831 ],
#        [0.7265421 ],
#        [0.70790213],
#        [0.74428326],
#        [0.75870764],
#        [0.76487726],
#        [0.76097506],
#        [0.77706385],
#        [0.7417046 ],
#        [0.7351115 ],
#        [0.7117575 ],
#        [0.71067464],
#        [0.7424237 ],
#        [0.74631137],
#        [0.72188276],
#        [0.7232751 ],
#        [0.7066832 ],
#        [0.7612069 ],
#        [0.7631768 ],
#        [0.79182625],
#        [0.79709625],
#        [0.7950006 ],
#        [0.7745321 ],
#        [0.81022394],
#        [0.7970562 ],
#        [0.8275855 ],
#        [0.8280885 ],
#        [0.83669245],
#        [0.8428516 ],
#        [0.826592  ],
#        [0.84268904],
#        [0.82462525],
#        [0.802197  ],
#        [0.80736876],
#        [0.7630608 ],
#        [0.75574446],
#        [0.719648  ],
#        [0.7475171 ],
#        [0.72254515],
#        [0.72860104],
#        [0.76137125],
#        [0.7469529 ],
#        [0.7361434 ],
#        [0.70766985],
#        [0.72319764],
#        [0.7086553 ],
#        [0.7133539 ],
#        [0.7153895 ],
#        [0.7207378 ],
#        [0.7136719 ],
#        [0.70958465],
#        [0.707882  ],
#        [0.7073385 ],
#        [0.6951789 ],
#        [0.67556125],
#        [0.66215897],
#        [0.6418926 ],
#        [0.639058  ],
#        [0.68740153],
#        [0.6380265 ],
#        [0.66088575],
#        [0.6325824 ],
#        [0.6255917 ],
#        [0.59963006],
#        [0.62272054],
#        [0.6235315 ],
#        [0.60800815],
#        [0.61139613],
#        [0.6184486 ],
#        [0.61355937],
#        [0.61516136],
#        [0.6435553 ],
#        [0.64307916],
#        [0.6473427 ],
#        [0.6367172 ],
#        [0.6336768 ],
#        [0.5992616 ],
#        [0.5206393 ],
#        [0.52472144],
#        [0.51676494],
#        [0.52225167],
#        [0.5345184 ],
#        [0.5505226 ],
#        [0.5645346 ],
#        [0.539834  ],
#        [0.56018835],
#        [0.6084828 ],
#        [0.5878761 ],
#        [0.5927485 ],
#        [0.57623434],
#        [0.5416951 ],
#        [0.5398832 ],
#        [0.5390724 ],
#        [0.55991286],
#        [0.5930971 ],
#        [0.59009373],
#        [0.56215656],
#        [0.55551815],
#        [0.5515187 ],
#        [0.53799564],
#        [0.5607807 ],
#        [0.567264  ],
#        [0.59159386],
#        [0.60527813],
#        [0.6065216 ],
#        [0.60805666],
#        [0.60615695],
#        [0.60040706],
#        [0.6172156 ],
#        [0.6207115 ],
#        [0.6172955 ],
#        [0.6303651 ],
#        [0.62675375],
#        [0.6355954 ],
#        [0.64196354],
#        [0.6506555 ],
#        [0.65640646],
#        [0.6607002 ],
#        [0.66201806],
#        [0.6608244 ],
#        [0.67492735],
#        [0.6887029 ],
#        [0.6981908 ],
#        [0.69280416],
#        [0.69311416],
#        [0.69983554],
#        [0.6815644 ],
#        [0.6860674 ],
#        [0.69494873],
#        [0.7040014 ],
#        [0.7010614 ],
#        [0.6891104 ],
#        [0.69087994],
#        [0.68603355],
#        [0.6892667 ],
#        [0.6686675 ],
#        [0.65634435],
#        [0.67119384],
#        [0.66996425],
#        [0.6685585 ],
#        [0.66457516],
#        [0.63273   ],
#        [0.636525  ],
#        [0.64068526],
#        [0.59472233],
#        [0.577249  ],
#        [0.56918174],
#        [0.5425859 ],
#        [0.5368545 ],
#        [0.52357906],
#        [0.5140106 ],
#        [0.527967  ],
#        [0.54865855],
#        [0.5542764 ],
#        [0.5355799 ],
#        [0.52467954],
#        [0.54311585],
#        [0.5385849 ],
#        [0.54089254],
#        [0.51100093],
#        [0.51145715],
#        [0.5042557 ],
#        [0.5053581 ],
#        [0.5083302 ],
#        [0.5077121 ],
#        [0.5150605 ],
#        [0.5156317 ],
#        [0.5114648 ],
#        [0.50031245],
#        [0.517885  ],
#        [0.51671064],
#        [0.5327138 ],
#        [0.5151007 ],
#        [0.5182381 ],
#        [0.53294927],
#        [0.5282504 ],
#        [0.52368945],
#        [0.51736987],
#        [0.5065257 ],
#        [0.51144975],
#        [0.5090634 ],
#        [0.50836295],
#        [0.508921  ],
#        [0.5325259 ],
#        [0.536678  ],
#        [0.54990506],
#        [0.5558737 ],
#        [0.5503178 ],
#        [0.5430463 ],
#        [0.5473241 ],
#        [0.5368033 ],
#        [0.54966766],
#        [0.54997873],
#        [0.555732  ],
#        [0.5395256 ],
#        [0.53776723],
#        [0.5691048 ],
#        [0.5739052 ],
#        [0.564093  ],
#        [0.55040324],
#        [0.5405805 ],
#        [0.5279771 ],
#        [0.54199123],
#        [0.53319585],
#        [0.539943  ],
#        [0.54449975],
#        [0.5506039 ],
#        [0.52609676],
#        [0.52235657],
#        [0.50503904],
#        [0.506938  ],
#        [0.50974274],
#        [0.50788957],
#        [0.5117995 ],
#        [0.5079167 ],
#        [0.502713  ]], dtype=float32), 'IXIC_valid_data_1_day': array([[0.92183832],
#        [0.92268511],
#        [0.92269733],
#        [0.94267034],
#        [0.94740009],
#        [0.95657651],
#        [0.96162712],
#        [0.97686752],
#        [0.9889794 ],
#        [0.9919225 ],
#        [0.99293587],
#        [0.98392034],
#        [0.95909713],
#        [0.96677191],
#        [0.98151357],
#        [0.98084457],
#        [0.99213613],
#        [0.98721627],
#        [0.99400373],
#        [1.        ],
#        [0.9809302 ],
#        [0.97343892],
#        [0.98003361],
#        [0.94676693],
#        [0.97416249],
#        [0.95109782],
#        [0.92441067],
#        [0.93638528],
#        [0.90854933],
#        [0.92169159],
#        [0.96513851],
#        [0.97455391],
#        [0.94918592],
#        [0.95983945],
#        [0.93939233],
#        [0.92286667],
#        [0.9537219 ],
#        [0.91748391],
#        [0.91647246],
#        [0.89871439],
#        [0.93260008],
#        [0.94961116],
#        [0.96198188],
#        [0.98248265],
#        [0.97405802],
#        [0.97259966],
#        [0.97027944],
#        [0.9611915 ],
#        [0.97886404],
#        [0.95909805],
#        [0.90993244],
#        [0.90811564],
#        [0.89447666],
#        [0.89512866],
#        [0.91494547],
#        [0.91823285],
#        [0.88233078],
#        [0.89051082],
#        [0.85411296],
#        [0.83843409],
#        [0.82091114],
#        [0.78467793],
#        [0.79278925],
#        [0.76307254],
#        [0.76333882],
#        [0.74552423],
#        [0.78483322],
#        [0.82898956],
#        [0.83897418],
#        [0.84570615],
#        [0.79501823],
#        [0.8156413 ],
#        [0.80789412],
#        [0.82471518],
#        [0.85255766],
#        [0.82388621],
#        [0.78676955],
#        [0.78674787],
#        [0.81956947],
#        [0.81809512],
#        [0.77976653],
#        [0.76389866],
#        [0.74822825],
#        [0.71585926],
#        [0.75689095],
#        [0.77768722],
#        [0.78302956],
#        [0.76242992],
#        [0.78308781],
#        [0.76294556],
#        [0.74182283],
#        [0.69642726],
#        [0.69309559],
#        [0.73637602],
#        [0.72455954],
#        [0.69763625],
#        [0.67292973],
#        [0.70749766],
#        [0.75340593],
#        [0.77017526],
#        [0.79643139],
#        [0.79122081],
#        [0.81665844],
#        [0.79913733],
#        [0.82446958],
#        [0.82234883],
#        [0.8398116 ],
#        [0.86472036],
#        [0.84803198],
#        [0.82716799],
#        [0.83102375],
#        [0.85652626],
#        [0.82562969],
#        [0.79595911],
#        [0.79675693],
#        [0.77922837],
#        [0.75109232],
#        [0.74729215],
#        [0.77288589],
#        [0.74536426],
#        [0.74360297],
#        [0.7706344 ],
#        [0.75496031],
#        [0.72876437],
#        [0.69721102],
#        [0.71278817],
#        [0.6644167 ],
#        [0.66424635],
#        [0.70024444],
#        [0.64972953],
#        [0.66867694],
#        [0.67128696],
#        [0.70902567],
#        [0.64813481],
#        [0.63185476],
#        [0.58279638],
#        [0.59356191],
#        [0.5584267 ],
#        [0.55905894],
#        [0.59989685],
#        [0.58651662],
#        [0.61678747],
#        [0.56349899],
#        [0.56070925],
#        [0.55752156],
#        [0.57451848],
#        [0.54903766],
#        [0.56505989],
#        [0.59384233],
#        [0.63058173],
#        [0.62590177],
#        [0.61772274],
#        [0.64806048],
#        [0.61944177],
#        [0.62401818],
#        [0.63473106],
#        [0.62636091],
#        [0.59512005],
#        [0.55614782],
#        [0.506207  ],
#        [0.50800588],
#        [0.53348495],
#        [0.49085836],
#        [0.50518324],
#        [0.53067637],
#        [0.52915029],
#        [0.54600241],
#        [0.5813258 ],
#        [0.57350989],
#        [0.54123682],
#        [0.54089336],
#        [0.52686021],
#        [0.5361852 ],
#        [0.554475  ],
#        [0.55820177],
#        [0.58261757],
#        [0.58393104],
#        [0.55921321],
#        [0.54906403],
#        [0.54745039],
#        [0.54779008],
#        [0.56672334],
#        [0.55803243],
#        [0.59125492],
#        [0.60861413],
#        [0.6238526 ],
#        [0.60263578],
#        [0.59779586],
#        [0.57708715],
#        [0.62129431],
#        [0.63354173],
#        [0.65500323],
#        [0.65296058],
#        [0.65105806],
#        [0.68110977],
#        [0.68604185],
#        [0.68011146],
#        [0.67887987],
#        [0.66471679],
#        [0.6986703 ],
#        [0.69162409],
#        [0.71677193],
#        [0.72437982],
#        [0.72198058],
#        [0.70650973],
#        [0.70907078],
#        [0.68459663],
#        [0.65414514],
#        [0.65411969],
#        [0.65884576],
#        [0.67839151],
#        [0.63157718],
#        [0.61990652],
#        [0.60724885],
#        [0.60095066],
#        [0.59802732],
#        [0.58351242],
#        [0.57542555],
#        [0.59866434],
#        [0.60527208],
#        [0.62881096],
#        [0.64330996],
#        [0.58376739],
#        [0.59186924],
#        [0.57612652],
#        [0.56634515],
#        [0.57449496],
#        [0.56414814],
#        [0.54487335],
#        [0.53044207],
#        [0.51172988],
#        [0.50561325],
#        [0.50811412],
#        [0.52901477],
#        [0.49945895],
#        [0.48422709],
#        [0.50679027],
#        [0.54075416],
#        [0.53814129],
#        [0.53105364],
#        [0.49145119],
#        [0.48107322],
#        [0.47016757],
#        [0.46931223],
#        [0.4911454 ],
#        [0.46030708],
#        [0.49365279],
#        [0.50274173],
#        [0.49409594],
#        [0.48791719],
#        [0.51095743],
#        [0.51969731],
#        [0.54289089],
#        [0.52142663],
#        [0.50464885],
#        [0.53379542],
#        [0.5230412 ],
#        [0.51388637],
#        [0.47944552],
#        [0.46233475],
#        [0.47478348],
#        [0.48318266],
#        [0.48804519],
#        [0.46329722],
#        [0.53489627],
#        [0.55457755],
#        [0.542618  ],
#        [0.55787816],
#        [0.5414363 ],
#        [0.53779508],
#        [0.53789854],
#        [0.52646217],
#        [0.54056598],
#        [0.55100129],
#        [0.54545387],
#        [0.52881345],
#        [0.52263002],
#        [0.56818923],
#        [0.56954882],
#        [0.56757766],
#        [0.54673159],
#        [0.52555704],
#        [0.52025614],
#        [0.53187131],
#        [0.5245908 ],
#        [0.53768032],
#        [0.54831877],
#        [0.54023475],
#        [0.50632929],
#        [0.49643876],
#        [0.48144305],
#        [0.48154467],
#        [0.49681135],
#        [0.47486535],
#        [0.47691084],
#        [0.46330292],
#        [0.45013622],
#        [0.47505068]]), 'IXIC_lstm_5_days': array([[0.8592582 , 0.85584205, 0.8514493 , 0.84642535, 0.86110026],
#        [0.85841566, 0.85519534, 0.8506959 , 0.8458853 , 0.8603772 ],
#        [0.8576832 , 0.8547295 , 0.85007507, 0.845586  , 0.85978776],
#        ...,
#        [0.56598914, 0.56129706, 0.5682756 , 0.55078816, 0.5727308 ],
#        [0.565072  , 0.56025743, 0.5674867 , 0.5496178 , 0.57194537],
#        [0.5629989 , 0.5580952 , 0.5655512 , 0.5473725 , 0.5699802 ]],
#       dtype=float32), 'IXIC_gru_5_days': array([[0.8309604 , 0.85159063, 0.8451043 , 0.8310097 , 0.84663236],
#        [0.8362147 , 0.85581875, 0.8502872 , 0.8361103 , 0.8509863 ],
#        [0.84169006, 0.8604831 , 0.85593104, 0.84154505, 0.85583967],
#        ...,
#        [0.522921  , 0.5448156 , 0.534692  , 0.52589536, 0.5374794 ],
#        [0.5158312 , 0.5394317 , 0.52855235, 0.51946765, 0.5319155 ],
#        [0.50904053, 0.53363794, 0.52203125, 0.51290554, 0.5259242 ]],
#       dtype=float32), 'IXIC_cnn_5_days': array([[0.8370694 , 0.8397181 , 0.83432066, 0.8435852 , 0.84589225],
#        [0.8448294 , 0.84967554, 0.844258  , 0.8536363 , 0.85524046],
#        [0.854557  , 0.8567805 , 0.8522888 , 0.8634474 , 0.860528  ],
#        ...,
#        [0.53345984, 0.52326953, 0.52170575, 0.5276798 , 0.52508867],
#        [0.5296832 , 0.5234103 , 0.5195047 , 0.5253388 , 0.5239694 ],
#        [0.53082633, 0.5253955 , 0.52034247, 0.5255976 , 0.527266  ]],
#       dtype=float32), 'IXIC_xgb_5_days': array([[0.9187364 , 0.90725327, 0.91415375, 0.9023919 , 0.91160065],
#        [0.9187078 , 0.9110446 , 0.8977825 , 0.9102866 , 0.91677135],
#        [0.92433804, 0.9172338 , 0.91997993, 0.9000784 , 0.893617  ],
#        ...,
#        [0.5059056 , 0.5128859 , 0.51221895, 0.5181621 , 0.5265409 ],
#        [0.50723785, 0.51193243, 0.5134091 , 0.52222806, 0.52935326],
#        [0.50763834, 0.5160363 , 0.51806825, 0.52790785, 0.52789474]],
#       dtype=float32), 'IXIC_valid_data_5_days': array([[0.91195625, 0.92080244, 0.90899441, 0.92183832, 0.92268511],
#        [0.92080244, 0.90899441, 0.92183832, 0.92268511, 0.92269733],
#        [0.90899441, 0.92183832, 0.92268511, 0.92269733, 0.94267034],
#        ...,
#        [0.48154467, 0.49681135, 0.47486535, 0.47691084, 0.46330292],
#        [0.49681135, 0.47486535, 0.47691084, 0.46330292, 0.45013622],
#        [0.47486535, 0.47691084, 0.46330292, 0.45013622, 0.47505068]]), 'IXIC_lstm_10_days': array([[0.8411356 , 0.83278227, 0.80075467, ..., 0.81577927, 0.86213124,
#         0.82131547],
#        [0.83968395, 0.83081555, 0.79800594, ..., 0.8136737 , 0.8596337 ,
#         0.81900144],
#        [0.83852965, 0.82929933, 0.7957866 , ..., 0.8120332 , 0.85766554,
#         0.817193  ],
#        ...,
#        [0.6279188 , 0.5939702 , 0.5221424 , ..., 0.55008054, 0.566204  ,
#         0.5408473 ],
#        [0.62789965, 0.59392923, 0.52215594, ..., 0.5499686 , 0.56613594,
#         0.5407474 ],
#        [0.6270081 , 0.59301645, 0.5212739 , ..., 0.5491339 , 0.5652121 ,
#         0.5398762 ]], dtype=float32), 'IXIC_gru_10_days': array([[0.83283705, 0.79982954, 0.8358557 , ..., 0.81604666, 0.8087687 ,
#         0.8296373 ],
#        [0.83309156, 0.80027485, 0.8366442 , ..., 0.8161463 , 0.80901396,
#         0.83008677],
#        [0.83446556, 0.80184424, 0.8387072 , ..., 0.81724226, 0.81042993,
#         0.8317171 ],
#        ...,
#        [0.5572896 , 0.5414629 , 0.5595103 , ..., 0.55704415, 0.532854  ,
#         0.5658326 ],
#        [0.555484  , 0.53986007, 0.5576513 , ..., 0.55526847, 0.5311732 ,
#         0.5642701 ],
#        [0.55463463, 0.5392253 , 0.5570125 , ..., 0.5542531 , 0.5303555 ,
#         0.56372637]], dtype=float32), 'IXIC_cnn_10_days': array([[0.8477811 , 0.83750033, 0.84238917, ..., 0.82333046, 0.8459853 ,
#         0.82948136],
#        [0.8479314 , 0.8370945 , 0.84240955, ..., 0.82383144, 0.84600616,
#         0.82951015],
#        [0.84787387, 0.83520794, 0.8405274 , ..., 0.8204552 , 0.8441265 ,
#         0.82991743],
#        ...,
#        [0.54700685, 0.53949064, 0.5375513 , ..., 0.5235599 , 0.5427367 ,
#         0.53625417],
#        [0.53448147, 0.5299788 , 0.52622575, ..., 0.5136062 , 0.5306261 ,
#         0.52351725],
#        [0.5247923 , 0.5223606 , 0.5176898 , ..., 0.5047492 , 0.52073234,
#         0.5142876 ]], dtype=float32), 'IXIC_xgb_10_days': array([[0.8642481 , 0.8847207 , 0.87689394, ..., 0.89591724, 0.90629625,
#         0.90735805],
#        [0.8818273 , 0.886636  , 0.8912159 , ..., 0.90574586, 0.90596086,
#         0.8768149 ],
#        [0.90301466, 0.8929184 , 0.88480765, ..., 0.8954583 , 0.88129973,
#         0.87202495],
#        ...,
#        [0.5389656 , 0.5376164 , 0.54444945, ..., 0.58702284, 0.59518677,
#         0.5864149 ],
#        [0.5440093 , 0.5598971 , 0.5532451 , ..., 0.59372467, 0.58937144,
#         0.5964221 ],
#        [0.55153555, 0.5583336 , 0.5592389 , ..., 0.5771651 , 0.581753  ,
#         0.5854143 ]], dtype=float32), 'IXIC_valid_data_10_days': array([[0.88389453, 0.89084858, 0.90255968, ..., 0.92183832, 0.92268511,
#         0.92269733],
#        [0.89084858, 0.90255968, 0.91265345, ..., 0.92268511, 0.92269733,
#         0.94267034],
#        [0.90255968, 0.91265345, 0.91195625, ..., 0.92269733, 0.94267034,
#         0.94740009],
#        ...,
#        [0.54831877, 0.54023475, 0.50632929, ..., 0.47486535, 0.47691084,
#         0.46330292],
#        [0.54023475, 0.50632929, 0.49643876, ..., 0.47691084, 0.46330292,
#         0.45013622],
#        [0.50632929, 0.49643876, 0.48144305, ..., 0.46330292, 0.45013622,
#         0.47505068]]), 'IXIC_lstm_1_month': array([[0.84549165, 0.8532355 , 0.85558295, ..., 0.87508345, 0.8769302 ,
#         0.8920529 ],
#        [0.84500086, 0.85267943, 0.8552087 , ..., 0.8746626 , 0.87657684,
#         0.89165497],
#        [0.8442897 , 0.85183287, 0.85455084, ..., 0.8740164 , 0.8760199 ,
#         0.8910208 ],
#        ...,
#        [0.50210524, 0.51087433, 0.5159898 , ..., 0.5432582 , 0.544917  ,
#         0.5516936 ],
#        [0.5012329 , 0.5101234 , 0.5151234 , ..., 0.5423473 , 0.5441991 ,
#         0.55104893],
#        [0.5006898 , 0.50951016, 0.5144839 , ..., 0.5417135 , 0.54359823,
#         0.55040306]], dtype=float32), 'IXIC_gru_1_month': array([[0.82784104, 0.82231563, 0.84261245, ..., 0.8525841 , 0.885873  ,
#         0.8578775 ],
#        [0.8266129 , 0.820319  , 0.8406051 , ..., 0.85019755, 0.8833127 ,
#         0.8559256 ],
#        [0.82534796, 0.81840706, 0.8385459 , ..., 0.84798574, 0.8807586 ,
#         0.8539249 ],
#        ...,
#        [0.5171978 , 0.49456224, 0.4816271 , ..., 0.51055694, 0.5087856 ,
#         0.5024858 ],
#        [0.5180598 , 0.49804348, 0.4849006 , ..., 0.51486504, 0.51298684,
#         0.5048349 ],
#        [0.52129775, 0.5043337 , 0.49101454, ..., 0.52190673, 0.52020806,
#         0.5099477 ]], dtype=float32), 'IXIC_cnn_1_month': array([[0.8620786 , 0.8773538 , 0.87251776, ..., 0.8823315 , 0.8821068 ,
#         0.8756234 ],
#        [0.86159545, 0.8758634 , 0.8707288 , ..., 0.8829593 , 0.88144684,
#         0.8740869 ],
#        [0.86070365, 0.8736974 , 0.8682951 , ..., 0.883241  , 0.8800658 ,
#         0.87225956],
#        ...,
#        [0.48148757, 0.49456635, 0.4894923 , ..., 0.50150466, 0.50059503,
#         0.49595326],
#        [0.48569155, 0.49538445, 0.4900505 , ..., 0.50797075, 0.5034031 ,
#         0.4977574 ],
#        [0.50123036, 0.5007395 , 0.497508  , ..., 0.5230551 , 0.51100886,
#         0.5116055 ]], dtype=float32), 'IXIC_xgb_1_month': array([[0.85773075, 0.85572755, 0.87139994, ..., 0.8787257 , 0.8841149 ,
#         0.89260536],
#        [0.85862505, 0.8556753 , 0.8705857 , ..., 0.88126785, 0.88655114,
#         0.89260536],
#        [0.858209  , 0.8602746 , 0.86834466, ..., 0.88126785, 0.88655114,
#         0.89260536],
#        ...,
#        [0.53674245, 0.54697603, 0.5407432 , ..., 0.5313652 , 0.5544813 ,
#         0.5398004 ],
#        [0.5468655 , 0.5476386 , 0.5419352 , ..., 0.56053674, 0.5373521 ,
#         0.5650195 ],
#        [0.5541647 , 0.5442304 , 0.55044234, ..., 0.5394577 , 0.56416315,
#         0.5608735 ]], dtype=float32), 'IXIC_valid_data_1_month': array([[0.89080246, 0.90542283, 0.90499567, ..., 0.94740009, 0.95657651,
#         0.96162712],
#        [0.90542283, 0.90499567, 0.89768218, ..., 0.95657651, 0.96162712,
#         0.97686752],
#        [0.90499567, 0.89768218, 0.85785571, ..., 0.96162712, 0.97686752,
#         0.9889794 ],
#        ...,
#        [0.542618  , 0.55787816, 0.5414363 , ..., 0.47486535, 0.47691084,
#         0.46330292],
#        [0.55787816, 0.5414363 , 0.53779508, ..., 0.47691084, 0.46330292,
#         0.45013622],
#        [0.5414363 , 0.53779508, 0.53789854, ..., 0.46330292, 0.45013622,
#         0.47505068]]), 'DJI_lstm_1_day': array([[0.86295974],
#        [0.8650678 ],
#        [0.86865413],
#        [0.8723964 ],
#        [0.8772714 ],
#        [0.8813766 ],
#        [0.8860904 ],
#        [0.890254  ],
#        [0.89426506],
#        [0.897745  ],
#        [0.9013294 ],
#        [0.9054021 ],
#        [0.90966916],
#        [0.91386163],
#        [0.9170389 ],
#        [0.9195074 ],
#        [0.9219666 ],
#        [0.9239837 ],
#        [0.9256288 ],
#        [0.92713666],
#        [0.92830753],
#        [0.92911255],
#        [0.92961717],
#        [0.93027306],
#        [0.9301467 ],
#        [0.92947996],
#        [0.9281919 ],
#        [0.92610556],
#        [0.9232548 ],
#        [0.91989195],
#        [0.9157426 ],
#        [0.9112267 ],
#        [0.9069607 ],
#        [0.9033512 ],
#        [0.90041316],
#        [0.8976876 ],
#        [0.895579  ],
#        [0.89400494],
#        [0.89341265],
#        [0.8934308 ],
#        [0.8942321 ],
#        [0.8951653 ],
#        [0.8958846 ],
#        [0.8967587 ],
#        [0.8992758 ],
#        [0.9014362 ],
#        [0.9048089 ],
#        [0.9089732 ],
#        [0.9120945 ],
#        [0.915428  ],
#        [0.9178388 ],
#        [0.91970235],
#        [0.92179054],
#        [0.9240652 ],
#        [0.9260617 ],
#        [0.92858994],
#        [0.93116015],
#        [0.93290573],
#        [0.93451035],
#        [0.9366558 ],
#        [0.9389229 ],
#        [0.9394923 ],
#        [0.93882203],
#        [0.9369694 ],
#        [0.93368024],
#        [0.9294357 ],
#        [0.9243064 ],
#        [0.91873753],
#        [0.9128822 ],
#        [0.90651083],
#        [0.9000274 ],
#        [0.8946798 ],
#        [0.89015245],
#        [0.8862089 ],
#        [0.88316715],
#        [0.88048875],
#        [0.87845486],
#        [0.87733215],
#        [0.8769655 ],
#        [0.8777402 ],
#        [0.8790922 ],
#        [0.8807696 ],
#        [0.8827808 ],
#        [0.8839618 ],
#        [0.8844357 ],
#        [0.884161  ],
#        [0.8829251 ],
#        [0.87988544],
#        [0.8755182 ],
#        [0.8702761 ],
#        [0.8644577 ],
#        [0.85947376],
#        [0.8544124 ],
#        [0.84920484],
#        [0.8432616 ],
#        [0.83683515],
#        [0.8314322 ],
#        [0.826926  ],
#        [0.82274026],
#        [0.81801546],
#        [0.8138999 ],
#        [0.8115856 ],
#        [0.81044286],
#        [0.8109679 ],
#        [0.8130307 ],
#        [0.8155534 ],
#        [0.81727016],
#        [0.8200259 ],
#        [0.8244502 ],
#        [0.8283223 ],
#        [0.83282673],
#        [0.83792233],
#        [0.84444433],
#        [0.85101885],
#        [0.8560695 ],
#        [0.8609177 ],
#        [0.8656581 ],
#        [0.8697807 ],
#        [0.87223935],
#        [0.87330645],
#        [0.8732881 ],
#        [0.87254417],
#        [0.8719998 ],
#        [0.87097585],
#        [0.8707807 ],
#        [0.86995435],
#        [0.86883926],
#        [0.8674199 ],
#        [0.86516446],
#        [0.862759  ],
#        [0.8608993 ],
#        [0.8582463 ],
#        [0.85487974],
#        [0.8515817 ],
#        [0.8481387 ],
#        [0.84418476],
#        [0.83963984],
#        [0.8354129 ],
#        [0.830795  ],
#        [0.8249874 ],
#        [0.8188761 ],
#        [0.8124027 ],
#        [0.80482304],
#        [0.7967743 ],
#        [0.7893889 ],
#        [0.78361917],
#        [0.77721024],
#        [0.7721399 ],
#        [0.7668722 ],
#        [0.7606982 ],
#        [0.75673604],
#        [0.75322014],
#        [0.7503588 ],
#        [0.7467989 ],
#        [0.74625814],
#        [0.7467438 ],
#        [0.7491248 ],
#        [0.7521398 ],
#        [0.7559908 ],
#        [0.7599011 ],
#        [0.76245844],
#        [0.76414263],
#        [0.76398396],
#        [0.7645908 ],
#        [0.7639283 ],
#        [0.76155543],
#        [0.7565854 ],
#        [0.7504114 ],
#        [0.74317765],
#        [0.73477304],
#        [0.725544  ],
#        [0.7172745 ],
#        [0.7099671 ],
#        [0.70260435],
#        [0.6967283 ],
#        [0.69162   ],
#        [0.6868752 ],
#        [0.68351644],
#        [0.68208766],
#        [0.68276143],
#        [0.6851768 ],
#        [0.68769896],
#        [0.6894501 ],
#        [0.69233066],
#        [0.69499445],
#        [0.6963698 ],
#        [0.69797885],
#        [0.6994841 ],
#        [0.6998977 ],
#        [0.70098555],
#        [0.7034676 ],
#        [0.70622003],
#        [0.7098934 ],
#        [0.71343946],
#        [0.71768254],
#        [0.7221852 ],
#        [0.7264106 ],
#        [0.7310515 ],
#        [0.73620933],
#        [0.74179137],
#        [0.7477339 ],
#        [0.75385636],
#        [0.7587814 ],
#        [0.7642442 ],
#        [0.7685877 ],
#        [0.773247  ],
#        [0.7780158 ],
#        [0.7833576 ],
#        [0.78865504],
#        [0.79423594],
#        [0.7986896 ],
#        [0.8021608 ],
#        [0.80457616],
#        [0.80643624],
#        [0.80814385],
#        [0.80805504],
#        [0.8070424 ],
#        [0.8047688 ],
#        [0.8013319 ],
#        [0.79697955],
#        [0.7908635 ],
#        [0.7842388 ],
#        [0.7767318 ],
#        [0.76907206],
#        [0.7612168 ],
#        [0.75394505],
#        [0.7468549 ],
#        [0.74047774],
#        [0.73532104],
#        [0.73029745],
#        [0.72491765],
#        [0.7186366 ],
#        [0.7137381 ],
#        [0.7084244 ],
#        [0.70288926],
#        [0.69706565],
#        [0.6901772 ],
#        [0.68326116],
#        [0.6762341 ],
#        [0.6683141 ],
#        [0.6603326 ],
#        [0.65216136],
#        [0.6442106 ],
#        [0.6392106 ],
#        [0.6344553 ],
#        [0.630376  ],
#        [0.6269162 ],
#        [0.62353766],
#        [0.6213456 ],
#        [0.620743  ],
#        [0.62091416],
#        [0.62260836],
#        [0.6255494 ],
#        [0.6294336 ],
#        [0.63313407],
#        [0.6386443 ],
#        [0.6459891 ],
#        [0.6528167 ],
#        [0.6591875 ],
#        [0.6666769 ],
#        [0.67552626],
#        [0.6858678 ],
#        [0.69640017],
#        [0.70676756],
#        [0.716959  ],
#        [0.7254666 ],
#        [0.73467904],
#        [0.7428409 ],
#        [0.75045204],
#        [0.75830317],
#        [0.7662711 ],
#        [0.7728213 ],
#        [0.7786457 ],
#        [0.7839466 ],
#        [0.78935635],
#        [0.79453546],
#        [0.79839325],
#        [0.8026699 ],
#        [0.8072072 ],
#        [0.8126687 ],
#        [0.8182882 ],
#        [0.8230295 ],
#        [0.82683104],
#        [0.8298112 ],
#        [0.83358586],
#        [0.834795  ],
#        [0.8356756 ],
#        [0.83666825],
#        [0.83731395],
#        [0.83775604],
#        [0.83784866],
#        [0.83714   ],
#        [0.8360111 ],
#        [0.8337227 ],
#        [0.8309146 ],
#        [0.82758486],
#        [0.8249538 ],
#        [0.8221164 ]], dtype=float32), 'DJI_gru_1_day': array([[0.92918783],
#        [0.9354859 ],
#        [0.9411433 ],
#        [0.9455312 ],
#        [0.9488681 ],
#        [0.95159525],
#        [0.9541588 ],
#        [0.9569261 ],
#        [0.96010673],
#        [0.9635089 ],
#        [0.9671944 ],
#        [0.971214  ],
#        [0.9751768 ],
#        [0.9783064 ],
#        [0.97998923],
#        [0.98053664],
#        [0.9804021 ],
#        [0.9800425 ],
#        [0.9793565 ],
#        [0.9782167 ],
#        [0.976224  ],
#        [0.97344613],
#        [0.9705769 ],
#        [0.968111  ],
#        [0.96464473],
#        [0.960068  ],
#        [0.9537301 ],
#        [0.94504124],
#        [0.93563783],
#        [0.9269065 ],
#        [0.92074996],
#        [0.9186377 ],
#        [0.9204574 ],
#        [0.92506796],
#        [0.93146235],
#        [0.93803906],
#        [0.94355816],
#        [0.94820994],
#        [0.9522285 ],
#        [0.9547741 ],
#        [0.9547982 ],
#        [0.9533157 ],
#        [0.9518686 ],
#        [0.9516056 ],
#        [0.95337796],
#        [0.957181  ],
#        [0.9625274 ],
#        [0.96845263],
#        [0.97402185],
#        [0.9791514 ],
#        [0.984176  ],
#        [0.988468  ],
#        [0.9913343 ],
#        [0.9926433 ],
#        [0.9924012 ],
#        [0.9912914 ],
#        [0.9899834 ],
#        [0.9885502 ],
#        [0.98668337],
#        [0.98340213],
#        [0.9779919 ],
#        [0.97023785],
#        [0.96008414],
#        [0.9485505 ],
#        [0.93679947],
#        [0.9256    ],
#        [0.91550756],
#        [0.9078782 ],
#        [0.90389335],
#        [0.90391695],
#        [0.90756565],
#        [0.91277057],
#        [0.91784126],
#        [0.9219248 ],
#        [0.92547053],
#        [0.9293628 ],
#        [0.93291587],
#        [0.93468314],
#        [0.9339278 ],
#        [0.93171835],
#        [0.92903847],
#        [0.92540807],
#        [0.9203412 ],
#        [0.9132262 ],
#        [0.90362346],
# ...
#        [0.5902063 ],
#        [0.5872275 ],
#        [0.59536266],
#        [0.5995014 ],
#        [0.58726156],
#        [0.5874524 ],
#        [0.5910511 ],
#        [0.59627664],
#        [0.58753127],
#        [0.59120256],
#        [0.5793255 ],
#        [0.57832867],
#        [0.57853997],
#        [0.5850254 ],
#        [0.596181  ],
#        [0.59995204],
#        [0.59263486],
#        [0.60079   ],
#        [0.60387826],
#        [0.5877259 ],
#        [0.6052904 ],
#        [0.5728047 ],
#        [0.58505714],
#        [0.59814316],
#        [0.6073247 ],
#        [0.6094674 ],
#        [0.6014582 ],
#        [0.6256924 ],
#        [0.6432091 ],
#        [0.64108527],
#        [0.64321566],
#        [0.66815466],
#        [0.66313833],
#        [0.68129915],
#        [0.66579753],
#        [0.6974188 ],
#        [0.69775945],
#        [0.70689046],
#        [0.687221  ],
#        [0.679391  ],
#        [0.7309023 ],
#        [0.7122973 ],
#        [0.7226154 ],
#        [0.73277587],
#        [0.67470443],
#        [0.6646768 ],
#        [0.69579273],
#        [0.66326207],
#        [0.68130296],
#        [0.7223315 ],
#        [0.6821487 ],
#        [0.66587955],
#        [0.6529917 ],
#        [0.64983195],
#        [0.6349462 ],
#        [0.64077294],
#        [0.62740195],
#        [0.6137057 ],
#        [0.62794816],
#        [0.61577034]], dtype=float32), 'SPX_valid_data_1_day': array([[0.91009548],
#        [0.91334266],
#        [0.9043124 ],
#        [0.9217946 ],
#        [0.92529574],
#        [0.9285351 ],
#        [0.93517008],
#        [0.94686138],
#        [0.95447725],
#        [0.9613036 ],
#        [0.96293321],
#        [0.95650524],
#        [0.9414456 ],
#        [0.94244595],
#        [0.95556747],
#        [0.95554782],
#        [0.96262049],
#        [0.95784158],
#        [0.96404288],
#        [0.9614717 ],
#        [0.95560258],
#        [0.95863492],
#        [0.96283933],
#        [0.92109132],
#        [0.94479047],
#        [0.91029867],
#        [0.88921365],
#        [0.91424532],
#        [0.89913492],
#        [0.91993853],
#        [0.95709137],
#        [0.96274164],
#        [0.94954991],
#        [0.96696571],
#        [0.95014386],
#        [0.93651424],
#        [0.96611781],
#        [0.95002652],
#        [0.93125873],
#        [0.91069725],
#        [0.9424303 ],
#        [0.96092468],
#        [0.97234639],
#        [0.99790161],
#        [0.99601043],
#        [0.99863236],
#        [0.99303284],
#        [0.98812896],
#        [1.        ],
#        [0.99881992],
#        [0.96249552],
#        [0.9607253 ],
#        [0.95329316],
#        [0.95065959],
#        [0.96737592],
#        [0.97256523],
#        [0.94625961],
#        [0.94775241],
#        [0.91424914],
#        [0.89691919],
#        [0.8773699 ],
#        [0.84423792],
#        [0.84900118],
#        [0.82802567],
#        [0.82547795],
#        [0.81632635],
#        [0.85748842],
#        [0.89019435],
#        [0.90230388],
#        [0.91904368],
#        [0.8753028 ],
#        [0.88432523],
#        [0.87781541],
#        [0.89253505],
#        [0.91818414],
#        [0.88571251],
#        [0.85232658],
#        [0.84569542],
#        [0.87281365],
#        [0.8743532 ],
#        [0.83732933],
#        [0.82506373],
#        [0.80782747],
#        [0.77685646],
#        [0.80155214],
#        [0.83904479],
#        [0.83485984],
#        [0.8084136 ],
#        [0.83978337],
#        [0.83077658],
#        [0.81724866],
#        [0.76731811],
#        [0.75544326],
#        [0.79732407],
#        [0.79014989],
#        [0.76857642],
#        [0.75638485],
#        [0.79129487],
#        [0.8285765 ],
#        [0.84960295],
#        [0.86970728],
#        [0.86894924],
#        [0.8886548 ],
#        [0.86701894],
#        [0.89199586],
#        [0.90094407],
#        [0.9136279 ],
#        [0.93554137],
#        [0.92415095],
#        [0.89600108],
#        [0.9020381 ],
#        [0.91641011],
#        [0.89393398],
#        [0.87675247],
#        [0.88420025],
#        [0.8795385 ],
#        [0.84993894],
#        [0.84404655],
#        [0.86324802],
#        [0.84214735],
#        [0.84179571],
#        [0.86935163],
#        [0.86827324],
#        [0.84256558],
#        [0.79494043],
#        [0.8044515 ],
#        [0.75720165],
#        [0.76062456],
#        [0.80108316],
#        [0.74029375],
#        [0.7494568 ],
#        [0.75731098],
#        [0.80603397],
#        [0.74613158],
#        [0.73693705],
#        [0.68531861],
#        [0.68915192],
#        [0.66341297],
#        [0.66142018],
#        [0.69807667],
#        [0.69187155],
#        [0.72346007],
#        [0.6589193 ],
#        [0.64997501],
#        [0.65019776],
#        [0.67848434],
#        [0.66587473],
#        [0.68043029],
#        [0.71134281],
#        [0.75057449],
#        [0.74037961],
#        [0.72829755],
#        [0.75783453],
#        [0.73115398],
#        [0.73619084],
#        [0.75152791],
#        [0.73397912],
#        [0.69570486],
#        [0.65000238],
#        [0.59090869],
#        [0.58537957],
#        [0.60667953],
#        [0.55853094],
#        [0.56168434],
#        [0.59683257],
#        [0.59491782],
#        [0.60892245],
#        [0.65425373],
#        [0.64970932],
#        [0.61901173],
#        [0.61794889],
#        [0.60487812],
#        [0.62048878],
#        [0.62285668],
#        [0.62820616],
#        [0.65069011],
#        [0.64942398],
#        [0.63185965],
#        [0.61793716],
#        [0.61128653],
#        [0.60683188],
#        [0.63527091],
#        [0.62264575],
#        [0.66400301],
#        [0.67307237],
#        [0.6883313 ],
#        [0.67374837],
#        [0.67578427],
#        [0.65789167],
#        [0.69796734],
#        [0.71704384],
#        [0.73965286],
#        [0.73509662],
#        [0.72437438],
#        [0.74937476],
#        [0.74811263],
#        [0.74547505],
#        [0.74347053],
#        [0.73659724],
#        [0.77089366],
#        [0.76973304],
#        [0.79821108],
#        [0.80485007],
#        [0.80799956],
#        [0.79582363],
#        [0.79961402],
#        [0.7780209 ],
#        [0.74266174],
#        [0.73904327],
#        [0.74374795],
#        [0.76654844],
#        [0.71127241],
#        [0.70070261],
#        [0.68333356],
#        [0.67115772],
#        [0.67578818],
#        [0.65914597],
#        [0.65286654],
#        [0.6808758 ],
#        [0.69115644],
#        [0.71506279],
#        [0.73188474],
#        [0.66243999],
#        [0.66764485],
#        [0.65019385],
#        [0.63924494],
#        [0.64962327],
#        [0.63244578],
#        [0.60665606],
#        [0.59417543],
#        [0.56887025],
#        [0.55394741],
#        [0.55091907],
#        [0.57895561],
#        [0.54825411],
#        [0.52682135],
#        [0.56308708],
#        [0.60704682],
#        [0.60405759],
#        [0.588912  ],
#        [0.54793757],
#        [0.53728173],
#        [0.52807957],
#        [0.52346475],
#        [0.55975786],
#        [0.52582491],
#        [0.56289953],
#        [0.5793229 ],
#        [0.56962438],
#        [0.55814409],
#        [0.59212789],
#        [0.60955161],
#        [0.63368844],
#        [0.62254806],
#        [0.61344349],
#        [0.65008052],
#        [0.63871738],
#        [0.63251227],
#        [0.59483969],
#        [0.5792877 ],
#        [0.59908331],
#        [0.61324812],
#        [0.62157509],
#        [0.59049457],
#        [0.6716931 ],
#        [0.68597896],
#        [0.67203692],
#        [0.68551008],
#        [0.67263869],
#        [0.66785979],
#        [0.67519814],
#        [0.66918049],
#        [0.69014054],
#        [0.69939355],
#        [0.69894813],
#        [0.67465103],
#        [0.67218536],
#        [0.72004489],
#        [0.71866161],
#        [0.7167586 ],
#        [0.68828838],
#        [0.66578878],
#        [0.66292061],
#        [0.67448303],
#        [0.66310034],
#        [0.68505293],
#        [0.69641988],
#        [0.68691292],
#        [0.64800559],
#        [0.63105086],
#        [0.61749164],
#        [0.61903911],
#        [0.64124163],
#        [0.6193399 ],
#        [0.62810456],
#        [0.62202051],
#        [0.60403413],
#        [0.6298473 ]]), 'SPX_lstm_5_days': array([[0.8101857 , 0.8158007 , 0.800797  , 0.81577635, 0.8107087 ],
#        [0.8104353 , 0.8161694 , 0.80106604, 0.8160351 , 0.8109807 ],
#        [0.8104532 , 0.81637585, 0.8011564 , 0.81606114, 0.81102693],
#        ...,
#        [0.674656  , 0.6854269 , 0.6734569 , 0.6837498 , 0.6791496 ],
#        [0.67384434, 0.6845553 , 0.6726392 , 0.6829824 , 0.6783343 ],
#        [0.67158186, 0.68230164, 0.67046815, 0.68079644, 0.6761017 ]],
#       dtype=float32), 'SPX_gru_5_days': array([[0.84015983, 0.8095761 , 0.82121325, 0.8353735 , 0.83903277],
#        [0.84569436, 0.81526977, 0.82807493, 0.84150475, 0.8454427 ],
#        [0.8518703 , 0.8214578 , 0.83540785, 0.84821725, 0.8524596 ],
#        ...,
#        [0.69139   , 0.66501695, 0.6612798 , 0.68031466, 0.6802672 ],
#        [0.68526274, 0.6585455 , 0.65370715, 0.67359984, 0.67335683],
#        [0.6786857 , 0.651931  , 0.6463157 , 0.6667201 , 0.66623396]],
#       dtype=float32), 'SPX_cnn_5_days': array([[0.82863474, 0.829537  , 0.8562799 , 0.85700613, 0.8258011 ],
#        [0.8336034 , 0.8319047 , 0.86447656, 0.8631325 , 0.8310935 ],
#        [0.8402089 , 0.83695567, 0.86836517, 0.8664634 , 0.83681965],
#        ...,
#        [0.69419837, 0.6979695 , 0.70054704, 0.70417625, 0.6854336 ],
#        [0.6913706 , 0.69339865, 0.6987939 , 0.69994   , 0.68240714],
#        [0.6932372 , 0.69733065, 0.7023116 , 0.7051391 , 0.68599665]],
#       dtype=float32), 'SPX_xgb_5_days': array([[0.8700179 , 0.87516993, 0.87373674, 0.88206327, 0.8820329 ],
#        [0.873164  , 0.8787354 , 0.88188916, 0.89130026, 0.8829055 ],
#        [0.8753282 , 0.88015074, 0.8777012 , 0.88727415, 0.88281727],
#        ...,
#        [0.6474932 , 0.6810528 , 0.6701442 , 0.6589856 , 0.6698687 ],
#        [0.6292475 , 0.644116  , 0.66594344, 0.6473806 , 0.68168324],
#        [0.6394749 , 0.65911067, 0.6588733 , 0.66284484, 0.6708931 ]],
#       dtype=float32), 'SPX_valid_data_5_days': array([[0.89825955, 0.90356982, 0.90166299, 0.91009548, 0.91334266],
#        [0.90356982, 0.90166299, 0.91009548, 0.91334266, 0.9043124 ],
#        [0.90166299, 0.91009548, 0.91334266, 0.9043124 , 0.9217946 ],
#        ...,
#        [0.61903911, 0.64124163, 0.6193399 , 0.62810456, 0.62202051],
#        [0.64124163, 0.6193399 , 0.62810456, 0.62202051, 0.60403413],
#        [0.6193399 , 0.62810456, 0.62202051, 0.60403413, 0.6298473 ]]), 'SPX_lstm_10_days': array([[0.85316086, 0.82288927, 0.81720865, ..., 0.83962995, 0.8351815 ,
#         0.8249637 ],
#        [0.85111266, 0.8212375 , 0.8157758 , ..., 0.83778864, 0.8333442 ,
#         0.8231568 ],
#        [0.8498708 , 0.82032114, 0.814948  , ..., 0.8366536 , 0.8322496 ,
#         0.8221289 ],
#        ...,
#        [0.7165812 , 0.6956613 , 0.70549244, ..., 0.7167193 , 0.70964533,
#         0.6893573 ],
#        [0.71757555, 0.69637686, 0.7062463 , ..., 0.7177636 , 0.71061116,
#         0.69006836],
#        [0.7177675 , 0.69643027, 0.70636433, ..., 0.7180268 , 0.71083367,
#         0.69011223]], dtype=float32), 'SPX_gru_10_days': array([[0.8145968 , 0.82712764, 0.83792984, ..., 0.8690759 , 0.81919354,
#         0.85544956],
#        [0.8153891 , 0.8277601 , 0.83876294, ..., 0.8700628 , 0.819943  ,
#         0.8562888 ],
#        [0.8173587 , 0.8294363 , 0.84084475, ..., 0.8724958 , 0.821732  ,
#         0.85828173],
#        ...,
#        [0.6989374 , 0.7133024 , 0.70368755, ..., 0.7337391 , 0.6996368 ,
#         0.7284071 ],
#        [0.6972431 , 0.71160215, 0.7015591 , ..., 0.73185474, 0.6975762 ,
#         0.7262377 ],
#        [0.6966633 , 0.7108298 , 0.7006187 , ..., 0.7312876 , 0.6965602 ,
#         0.7253159 ]], dtype=float32), 'SPX_cnn_10_days': array([[0.8227006 , 0.8328289 , 0.81939507, ..., 0.8127315 , 0.8226804 ,
#         0.8170458 ],
#        [0.8237595 , 0.83204937, 0.8206237 , ..., 0.8132359 , 0.82231647,
#         0.81839967],
#        [0.82561386, 0.8306222 , 0.8257582 , ..., 0.8180002 , 0.8208047 ,
#         0.82470506],
#        ...,
#        [0.6903582 , 0.70196116, 0.68815356, ..., 0.68927723, 0.6899866 ,
#         0.6916408 ],
#        [0.6768037 , 0.6893815 , 0.67521834, ..., 0.6835499 , 0.6809    ,
#         0.68482214],
#        [0.66835266, 0.6796349 , 0.66901135, ..., 0.68238163, 0.6740298 ,
#         0.6828208 ]], dtype=float32), 'SPX_xgb_10_days': array([[0.83789426, 0.84226024, 0.8387135 , ..., 0.8621492 , 0.8783648 ,
#         0.8857437 ],
#        [0.8539481 , 0.84344035, 0.84081286, ..., 0.8725812 , 0.87313926,
#         0.87156355],
#        [0.8576781 , 0.8442546 , 0.8427857 , ..., 0.87766343, 0.87403095,
#         0.8715173 ],
#        ...,
#        [0.68389755, 0.6919817 , 0.7048549 , ..., 0.73939717, 0.7558544 ,
#         0.7486221 ],
#        [0.7221299 , 0.7245773 , 0.7260501 , ..., 0.7567923 , 0.7618525 ,
#         0.7685668 ],
#        [0.68322986, 0.701081  , 0.7290608 , ..., 0.76322806, 0.76168364,
#         0.75732565]], dtype=float32), 'SPX_valid_data_10_days': array([[0.85999302, 0.87293099, 0.8788274 , ..., 0.91009548, 0.91334266,
#         0.9043124 ],
#        [0.87293099, 0.8788274 , 0.89178865, ..., 0.91334266, 0.9043124 ,
#         0.9217946 ],
#        [0.8788274 , 0.89178865, 0.89825955, ..., 0.9043124 , 0.9217946 ,
#         0.92529574],
#        ...,
#        [0.69641988, 0.68691292, 0.64800559, ..., 0.6193399 , 0.62810456,
#         0.62202051],
#        [0.68691292, 0.64800559, 0.63105086, ..., 0.62810456, 0.62202051,
#         0.60403413],
#        [0.64800559, 0.63105086, 0.61749164, ..., 0.62202051, 0.60403413,
#         0.6298473 ]]), 'SPX_lstm_1_month': array([[0.86443657, 0.8575103 , 0.86962354, ..., 0.8586298 , 0.8744752 ,
#         0.9029361 ],
#        [0.8637906 , 0.85673374, 0.8688496 , ..., 0.85773015, 0.8733509 ,
#         0.9022116 ],
#        [0.8628718 , 0.8556352 , 0.8678198 , ..., 0.8565879 , 0.87196636,
#         0.90122294],
#        ...,
#        [0.63877773, 0.62856764, 0.63945717, ..., 0.6606643 , 0.66176736,
#         0.6828072 ],
#        [0.64255667, 0.6317914 , 0.64290893, ..., 0.66374636, 0.6648256 ,
#         0.6864491 ],
#        [0.64587116, 0.6347239 , 0.6461484 , ..., 0.66660666, 0.6677673 ,
#         0.68971485]], dtype=float32), 'SPX_gru_1_month': array([[0.81904894, 0.81622773, 0.826359  , ..., 0.8506602 , 0.86228216,
#         0.85498077],
#        [0.81560963, 0.8123612 , 0.82254916, ..., 0.84644634, 0.8585605 ,
#         0.8509602 ],
#        [0.8123324 , 0.808791  , 0.81891906, ..., 0.84259146, 0.8550677 ,
#         0.8472788 ],
#        ...,
#        [0.5906954 , 0.5764563 , 0.5837723 , ..., 0.6104568 , 0.6234702 ,
#         0.6213355 ],
#        [0.5959573 , 0.5827083 , 0.5895901 , ..., 0.6168777 , 0.6294227 ,
#         0.627638  ],
#        [0.6029329 , 0.5906664 , 0.5972929 , ..., 0.6253878 , 0.6370859 ,
#         0.63595825]], dtype=float32), 'SPX_cnn_1_month': array([[0.8122817 , 0.87880933, 0.82361   , ..., 0.8555787 , 0.8491815 ,
#         0.8323827 ],
#        [0.81162906, 0.8771062 , 0.8233572 , ..., 0.855587  , 0.8483964 ,
#         0.83201385],
#        [0.8101586 , 0.87471217, 0.82274735, ..., 0.85503006, 0.8467302 ,
#         0.83088285],
#        ...,
#        [0.5658328 , 0.6135902 , 0.5810466 , ..., 0.587956  , 0.59823   ,
#         0.59041023],
#        [0.57462746, 0.6229579 , 0.591853  , ..., 0.5993382 , 0.60807824,
#         0.60001576],
#        [0.5864897 , 0.628761  , 0.60951173, ..., 0.61934114, 0.61858636,
#         0.616618  ]], dtype=float32), 'SPX_xgb_1_month': array([[0.81438416, 0.82096773, 0.8381847 , ..., 0.86289924, 0.860167  ,
#         0.86486703],
#        [0.8229508 , 0.82141805, 0.8410153 , ..., 0.8388096 , 0.8333477 ,
#         0.82415557],
#        [0.83841175, 0.8248698 , 0.8410153 , ..., 0.8212993 , 0.80262065,
#         0.8185185 ],
#        ...,
#        [0.64509594, 0.6236719 , 0.6408967 , ..., 0.6462018 , 0.6644402 ,
#         0.65402836],
#        [0.63842046, 0.63454354, 0.64692867, ..., 0.6718058 , 0.66676944,
#         0.6561323 ],
#        [0.643104  , 0.64350647, 0.68515736, ..., 0.67161804, 0.6512957 ,
#         0.654731  ]], dtype=float32), 'SPX_valid_data_1_month': array([[0.84333926, 0.86418197, 0.86672187, ..., 0.92529574, 0.9285351 ,
#         0.93517008],
#        [0.86418197, 0.86672187, 0.86188821, ..., 0.9285351 , 0.93517008,
#         0.94686138],
#        [0.86672187, 0.86188821, 0.82653287, ..., 0.93517008, 0.94686138,
#         0.95447725],
#        ...,
#        [0.67203692, 0.68551008, 0.67263869, ..., 0.6193399 , 0.62810456,
#         0.62202051],
#        [0.68551008, 0.67263869, 0.66785979, ..., 0.62810456, 0.62202051,
#         0.60403413],
#        [0.67263869, 0.66785979, 0.67519814, ..., 0.62202051, 0.60403413,
#         0.6298473 ]])}

# %%
pred_foo_20d.keys()
# Out:
# dict_keys(['IXIC_lstm_1_day', 'IXIC_gru_1_day', 'IXIC_cnn_1_day', 'IXIC_xgb_1_day', 'IXIC_valid_data_1_day', 'IXIC_lstm_5_days', 'IXIC_gru_5_days', 'IXIC_cnn_5_days', 'IXIC_xgb_5_days', 'IXIC_valid_data_5_days', 'IXIC_lstm_10_days', 'IXIC_gru_10_days', 'IXIC_cnn_10_days', 'IXIC_xgb_10_days', 'IXIC_valid_data_10_days', 'IXIC_lstm_1_month', 'IXIC_gru_1_month', 'IXIC_cnn_1_month', 'IXIC_xgb_1_month', 'IXIC_valid_data_1_month', 'DJI_lstm_1_day', 'DJI_gru_1_day', 'DJI_cnn_1_day', 'DJI_xgb_1_day', 'DJI_valid_data_1_day', 'DJI_lstm_5_days', 'DJI_gru_5_days', 'DJI_cnn_5_days', 'DJI_xgb_5_days', 'DJI_valid_data_5_days', 'DJI_lstm_10_days', 'DJI_gru_10_days', 'DJI_cnn_10_days', 'DJI_xgb_10_days', 'DJI_valid_data_10_days', 'DJI_lstm_1_month', 'DJI_gru_1_month', 'DJI_cnn_1_month', 'DJI_xgb_1_month', 'DJI_valid_data_1_month', 'SPX_lstm_1_day', 'SPX_gru_1_day', 'SPX_cnn_1_day', 'SPX_xgb_1_day', 'SPX_valid_data_1_day', 'SPX_lstm_5_days', 'SPX_gru_5_days', 'SPX_cnn_5_days', 'SPX_xgb_5_days', 'SPX_valid_data_5_days', 'SPX_lstm_10_days', 'SPX_gru_10_days', 'SPX_cnn_10_days', 'SPX_xgb_10_days', 'SPX_valid_data_10_days', 'SPX_lstm_1_month', 'SPX_gru_1_month', 'SPX_cnn_1_month', 'SPX_xgb_1_month', 'SPX_valid_data_1_month'])

# %%
def take_maximum(dictionary):

  new_arrays = {}
  for dataset in ['IXIC', 'DJI', 'SPX']:
    for days in ['1_day', '5_days', '10_days', '1_month']:
      new_array = np.maximum(np.maximum(np.maximum(dictionary[f"{dataset}_lstm_{days}"], 
                                                  dictionary[f"{dataset}_gru_{days}"]), 
                                                  dictionary[f"{dataset}_cnn_{days}"]), 
                                                  dictionary[f"{dataset}_xgb_{days}"])
      new_arrays.update({f"{dataset}_{days}": new_array})
  return new_arrays

def take_minimum(dictionary):

  new_arrays = {}
  for dataset in ['IXIC', 'DJI', 'SPX']:
    for days in ['1_day', '5_days', '10_days', '1_month']:
      new_array = np.minimum(np.minimum(np.minimum(dictionary[f"{dataset}_lstm_{days}"], 
                                                  dictionary[f"{dataset}_gru_{days}"]), 
                                                  dictionary[f"{dataset}_cnn_{days}"]), 
                                                  dictionary[f"{dataset}_xgb_{days}"])
      new_arrays.update({f"{dataset}_{days}": new_array})
  return new_arrays  

def take_maximum_gru_cnn(dictionary):

  new_arrays = {}
  for dataset in ['IXIC', 'DJI', 'SPX']:
    for days in ['1_day', '5_days', '10_days', '1_month']:
      new_array = np.maximum(dictionary[f"{dataset}_cnn_{days}"], 
                            dictionary[f"{dataset}_gru_{days}"])
                                                   
                                                  
      new_arrays.update({f"{dataset}_{days}": new_array})
  return new_arrays

def take_minimum_gru_cnn(dictionary):

  new_arrays = {}
  for dataset in ['IXIC', 'DJI', 'SPX']:
    for days in ['1_day', '5_days', '10_days', '1_month']:
      new_array = np.minimum(dictionary[f"{dataset}_cnn_{days}"], 
                            dictionary[f"{dataset}_gru_{days}"])
                                                  
      new_arrays.update({f"{dataset}_{days}": new_array})
  return new_arrays

def take_avg(dictionary):

  new_arrays = {}
  for dataset in ['IXIC', 'DJI', 'SPX']:
    for days in ['1_day', '5_days', '10_days', '1_month']:
      new_array = (dictionary[f"{dataset}_lstm_{days}"] +
                  dictionary[f"{dataset}_gru_{days}"] +
                  dictionary[f"{dataset}_cnn_{days}"] +
                  dictionary[f"{dataset}_xgb_{days}"]) / 4
      new_arrays.update({f"{dataset}_{days}": new_array})
  return new_arrays

def take_avg_from_gru_cnn(dictionary):

  new_arrays = {}
  for dataset in ['IXIC', 'DJI', 'SPX']:
    for days in ['1_day', '5_days', '10_days', '1_month']:
      new_array = (dictionary[f"{dataset}_gru_{days}"] +
                  dictionary[f"{dataset}_cnn_{days}"]) / 2
      new_arrays.update({f"{dataset}_{days}": new_array})
  return new_arrays

# %%
def calc_ensemble_err_rmse(dictionary, dictionary_scalers):
  ensemble_arr = {}

  friendly_max_arr = []
  friendly_min_arr = []
  friendly_avg_arr = []

  friendly_max_gru_cnn_arr = []
  friendly_min_gru_cnn_arr = []
  friendly_avg_gru_cnn_arr = []

  foo_avg_arr = take_avg(dictionary)
  foo_min_arr = take_minimum(dictionary)
  foo_max_arr = take_maximum(dictionary)

  foo_min_gru_cnn_arr = take_minimum_gru_cnn(dictionary)
  foo_max_gru_cnn_arr = take_maximum_gru_cnn(dictionary)
  foo_avg_gru_cnn_arr = take_avg_from_gru_cnn(dictionary)


  for dataset in ['IXIC', 'DJI', 'SPX']:
    foo_list_max = f"{dataset} "
    foo_list_min = f"{dataset} "
    foo_list_avg = f"{dataset} "

    foo_list_max_gru_cnn = f"{dataset} "
    foo_list_min_gru_cnn = f"{dataset} "
    foo_list_avg_gru_cnn = f"{dataset} "

    for days in ['1_day', '5_days', '10_days', '1_month']:
      
      #
      #
      ens_val_avg = my_rmse(dictionary_scalers[f"{dataset}_scaler"].inverse_transform(dictionary[f"{dataset}_valid_data_{days}"]), 
                            dictionary_scalers[f"{dataset}_scaler"].inverse_transform(foo_avg_arr[f"{dataset}_{days}"]))
      ensemble_arr.update({f"{dataset}_{days}_avg": ens_val_avg})
      #
      #
      ens_val_min = my_rmse(dictionary_scalers[f"{dataset}_scaler"].inverse_transform(dictionary[f"{dataset}_valid_data_{days}"]), 
                            dictionary_scalers[f"{dataset}_scaler"].inverse_transform(foo_min_arr[f"{dataset}_{days}"]))
      ensemble_arr.update({f"{dataset}_{days}_min": ens_val_min})
      #
      #
      ens_val_max = my_rmse(dictionary_scalers[f"{dataset}_scaler"].inverse_transform(dictionary[f"{dataset}_valid_data_{days}"]), 
                            dictionary_scalers[f"{dataset}_scaler"].inverse_transform(foo_max_arr[f"{dataset}_{days}"]))
      ensemble_arr.update({f"{dataset}_{days}_max": ens_val_max})
      #
      #
      ens_val_max_gru_cnn = my_rmse(dictionary_scalers[f"{dataset}_scaler"].inverse_transform(dictionary[f"{dataset}_valid_data_{days}"]), 
                            dictionary_scalers[f"{dataset}_scaler"].inverse_transform(foo_max_gru_cnn_arr[f"{dataset}_{days}"]))
      ensemble_arr.update({f"{dataset}_{days}_max": ens_val_max_gru_cnn})
      #
      #
      ens_val_min_gru_cnn = my_rmse(dictionary_scalers[f"{dataset}_scaler"].inverse_transform(dictionary[f"{dataset}_valid_data_{days}"]), 
                            dictionary_scalers[f"{dataset}_scaler"].inverse_transform(foo_min_gru_cnn_arr[f"{dataset}_{days}"]))
      ensemble_arr.update({f"{dataset}_{days}_max": ens_val_min_gru_cnn})
      #
      #
      ens_val_avg_gru_cnn = my_rmse(dictionary_scalers[f"{dataset}_scaler"].inverse_transform(dictionary[f"{dataset}_valid_data_{days}"]), 
                                  dictionary_scalers[f"{dataset}_scaler"].inverse_transform(foo_avg_gru_cnn_arr[f"{dataset}_{days}"]))
      ensemble_arr.update({f"{dataset}_{days}_avg_gru_cnn": ens_val_avg_gru_cnn})

      foo_list_max += f"{ens_val_max} & "
      foo_list_min += f"{ens_val_min} & "
      foo_list_avg += f"{ens_val_avg} & "
      foo_list_max_gru_cnn += f"{ens_val_max_gru_cnn} & "
      foo_list_min_gru_cnn += f"{ens_val_min_gru_cnn} & "
      foo_list_avg_gru_cnn += f"{ens_val_avg_gru_cnn} & "

   
    friendly_max_arr.append(foo_list_max)
    friendly_min_arr.append(foo_list_min)
    friendly_avg_arr.append(foo_list_avg)

    friendly_max_gru_cnn_arr.append(foo_list_max_gru_cnn)
    friendly_min_gru_cnn_arr.append(foo_list_min_gru_cnn)
    friendly_avg_gru_cnn_arr.append(foo_list_avg_gru_cnn)

  return ensemble_arr, friendly_max_arr, friendly_min_arr, friendly_avg_arr, friendly_max_gru_cnn_arr, friendly_min_gru_cnn_arr, friendly_avg_gru_cnn_arr

# %%
pred_foo_20d = 0
pred_foo_20d_scalers = 0

with open(f"{CFG.data_path}/20d/ensemble/prediction_ypred_yvalid.pkl", 'rb') as f:
    pred_foo_20d = pickle.load(f)

with open(f"{CFG.data_path}/20d/ensemble/local_scalers.pkl", 'rb') as f:
    pred_foo_20d_scalers = pickle.load(f)

# %%
_, _, _, _, friendly_max_gru_cnn_arr, friendly_min_gru_cnn_arr, _ = calc_ensemble_err_rmse(pred_foo_80d, pred_foo_80d_scalers)

# %%
friendly_max_gru_cnn_arr, friendly_min_gru_cnn_arr
# Out:
# (['IXIC 568.621 & 700.1288 & 755.758 & 1033.6339 & ',
#   'DJI 996.5545 & 1016.1474 & 1252.8736 & 1886.8288 & ',
#   'SPX 160.5248 & 202.4357 & 244.7957 & 232.3758 & '],
#  ['IXIC 445.8942 & 632.354 & 661.6066 & 1110.9428 & ',
#   'DJI 831.8319 & 1063.3606 & 1306.868 & 1623.5928 & ',
#   'SPX 123.837 & 148.6444 & 162.0672 & 251.3738 & '])

# %%
pred_foo_50d = 0
pred_foo_50d_scalers = 0

with open(f"{CFG.data_path}/50d/ensemble/prediction_ypred_yvalid.pkl", 'rb') as f:
    pred_foo_50d = pickle.load(f)

with open(f"{CFG.data_path}/50d/ensemble/local_scalers.pkl", 'rb') as f:
    pred_foo_50d_scalers = pickle.load(f)

# %%
ens_50d_rmse, friendly_max_arr, friendly_min_arr, friendly_avg_arr, friendly_avg_gru_cnn_arr = calc_ensemble_err_rmse(pred_foo_50d, pred_foo_50d_scalers)

# %%
friendly_avg_gru_cnn_arr
# Out:
# ['IXIC 519.4785 & 573.1805 & 722.204 & 930.8661 & ',
#  'DJI 832.7307 & 980.3297 & 1189.3685 & 1606.6033 & ',
#  'SPX 124.9443 & 146.3977 & 167.6845 & 232.7335 & ']

# %%
pred_foo_80d = 0
pred_foo_80d_scalers = 0

with open(f"{CFG.data_path}/80d/ensemble/prediction_ypred_yvalid.pkl", 'rb') as f:
    pred_foo_80d = pickle.load(f)

with open(f"{CFG.data_path}/80d/ensemble/local_scalers.pkl", 'rb') as f:
    pred_foo_80d_scalers = pickle.load(f)

# %%
ens_80d_rmse, friendly_max_arr, friendly_min_arr, friendly_avg_arr, friendly_avg_gru_cnn_arr  = calc_ensemble_err_rmse(pred_foo_80d, pred_foo_80d_scalers)

# %%
friendly_max_arr, friendly_min_arr, friendly_avg_arr, friendly_avg_gru_cnn_arr
# Out:
# (['IXIC 651.2994 & 897.883 & 973.3546 & 1300.4148 & ',
#   'DJI 1131.2762 & 1313.6121 & 1527.0639 & 2341.2278 & ',
#   'SPX 168.2734 & 230.325 & 267.429 & 288.4047 & '],
#  ['IXIC 538.8819 & 652.9886 & 772.8444 & 1131.5247 & ',
#   'DJI 1140.6272 & 1244.1807 & 1474.0222 & 2086.2189 & ',
#   'SPX 163.1406 & 198.8585 & 218.8819 & 282.7971 & '],
#  ['IXIC 487.5528 & 649.1597 & 746.0715 & 1045.5957 & ',
#   'DJI 913.9161 & 1025.6347 & 1267.8063 & 1687.0171 & ',
#   'SPX 133.0207 & 167.2679 & 188.0037 & 241.1517 & '],
#  ['IXIC 473.3459 & 626.4082 & 687.9141 & 1001.0658 & ',
#   'DJI 901.7551 & 987.7348 & 1205.5848 & 1615.8264 & ',
#   'SPX 129.5351 & 166.5952 & 187.7399 & 232.1105 & '])

# %%
ens_20d_rmse = calc_ensemble_err_rmse()

# %%
with open(f"{CFG.data_path}/20d/ensemble/ens_rmse_errors.pkl", 'wb') as f:
  pickle.dump(ens_20d_rmse, f)

# %%
ens_20d_rmse
# Out:
# {'IXIC_1_day_avg': 483.5827,
#  'IXIC_1_day_min': 586.0833,
#  'IXIC_1_day_max': 553.4261,
#  'IXIC_5_days_avg': 603.5157,
#  'IXIC_5_days_min': 657.4704,
#  'IXIC_5_days_max': 763.6896,
#  'IXIC_10_days_avg': 705.8025,
#  'IXIC_10_days_min': 786.3832,
#  'IXIC_10_days_max': 863.656,
#  'IXIC_1_month_avg': 955.7435,
#  'IXIC_1_month_min': 948.1783,
#  'IXIC_1_month_max': 1089.8476,
#  'DJI_1_day_avg': 831.4623,
#  'DJI_1_day_min': 969.9553,
#  'DJI_1_day_max': 1021.2635,
#  'DJI_5_days_avg': 1090.7445,
#  'DJI_5_days_min': 1195.8833,
#  'DJI_5_days_max': 1202.8723,
#  'DJI_10_days_avg': 1269.4625,
#  'DJI_10_days_min': 1499.7353,
#  'DJI_10_days_max': 1401.337,
#  'DJI_1_month_avg': 1717.6117,
#  'DJI_1_month_min': 2178.683,
#  'DJI_1_month_max': 1969.3633,
#  'SPX_1_day_avg': 123.0113,
#  'SPX_1_day_min': 155.6919,
#  'SPX_1_day_max': 147.5459,
#  'SPX_5_days_avg': 157.6765,
#  'SPX_5_days_min': 201.2516,
#  'SPX_5_days_max': 172.3794,
#  'SPX_10_days_avg': 181.0714,
#  'SPX_10_days_min': 218.5319,
#  'SPX_10_days_max': 199.9963,
#  'SPX_1_month_avg': 234.5758,
#  'SPX_1_month_min': 255.6928,
#  'SPX_1_month_max': 256.6689}

# %%
prediction_dict3 = {}
prediction_dict3, local_scaler3 = ensemble_pipe(20, '20d', 'ensemble')
# Out:
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# 10/10 [==============================] - 44s 197ms/step
# IXIC_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 4s 51ms/step
# IXIC_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# 10/10 [==============================] - 0s 5ms/step
# IXIC_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# IXIC_xgb_1_day DONE
# valid is [[0.92183832]
#  [0.92268511]
#  [0.92269733]
#  [0.94267034]
#  [0.94740009]
#  [0.95657651]
#  [0.96162712]
#  [0.97686752]
#  [0.9889794 ]
#  [0.9919225 ]
#  [0.99293587]
#  [0.98392034]
#  [0.95909713]
#  [0.96677191]
#  [0.98151357]
#  [0.98084457]
#  [0.99213613]
#  [0.98721627]
#  [0.99400373]
#  [1.        ]
#  [0.9809302 ]
#  [0.97343892]
#  [0.98003361]
#  [0.94676693]
#  [0.97416249]
#  [0.95109782]
#  [0.92441067]
#  [0.93638528]
#  [0.90854933]
#  [0.92169159]
#  [0.96513851]
#  [0.97455391]
#  [0.94918592]
#  [0.95983945]
#  [0.93939233]
#  [0.92286667]
#  [0.9537219 ]
#  [0.91748391]
#  [0.91647246]
#  [0.89871439]
#  [0.93260008]
#  [0.94961116]
#  [0.96198188]
#  [0.98248265]
#  [0.97405802]
#  [0.97259966]
#  [0.97027944]
#  [0.9611915 ]
#  [0.97886404]
#  [0.95909805]
#  [0.90993244]
#  [0.90811564]
#  [0.89447666]
#  [0.89512866]
#  [0.91494547]
#  [0.91823285]
#  [0.88233078]
#  [0.89051082]
#  [0.85411296]
#  [0.83843409]
#  [0.82091114]
#  [0.78467793]
#  [0.79278925]
#  [0.76307254]
#  [0.76333882]
#  [0.74552423]
#  [0.78483322]
#  [0.82898956]
#  [0.83897418]
#  [0.84570615]
#  [0.79501823]
#  [0.8156413 ]
#  [0.80789412]
#  [0.82471518]
#  [0.85255766]
#  [0.82388621]
#  [0.78676955]
#  [0.78674787]
#  [0.81956947]
#  [0.81809512]
#  [0.77976653]
#  [0.76389866]
#  [0.74822825]
#  [0.71585926]
#  [0.75689095]
#  [0.77768722]
#  [0.78302956]
#  [0.76242992]
#  [0.78308781]
#  [0.76294556]
#  [0.74182283]
#  [0.69642726]
#  [0.69309559]
#  [0.73637602]
#  [0.72455954]
#  [0.69763625]
#  [0.67292973]
#  [0.70749766]
#  [0.75340593]
#  [0.77017526]
#  [0.79643139]
#  [0.79122081]
#  [0.81665844]
#  [0.79913733]
#  [0.82446958]
#  [0.82234883]
#  [0.8398116 ]
#  [0.86472036]
#  [0.84803198]
#  [0.82716799]
#  [0.83102375]
#  [0.85652626]
#  [0.82562969]
#  [0.79595911]
#  [0.79675693]
#  [0.77922837]
#  [0.75109232]
#  [0.74729215]
#  [0.77288589]
#  [0.74536426]
#  [0.74360297]
#  [0.7706344 ]
#  [0.75496031]
#  [0.72876437]
#  [0.69721102]
#  [0.71278817]
#  [0.6644167 ]
#  [0.66424635]
#  [0.70024444]
#  [0.64972953]
#  [0.66867694]
#  [0.67128696]
#  [0.70902567]
#  [0.64813481]
#  [0.63185476]
#  [0.58279638]
#  [0.59356191]
#  [0.5584267 ]
#  [0.55905894]
#  [0.59989685]
#  [0.58651662]
#  [0.61678747]
#  [0.56349899]
#  [0.56070925]
#  [0.55752156]
#  [0.57451848]
#  [0.54903766]
#  [0.56505989]
#  [0.59384233]
#  [0.63058173]
#  [0.62590177]
#  [0.61772274]
#  [0.64806048]
#  [0.61944177]
#  [0.62401818]
#  [0.63473106]
#  [0.62636091]
#  [0.59512005]
#  [0.55614782]
#  [0.506207  ]
#  [0.50800588]
#  [0.53348495]
#  [0.49085836]
#  [0.50518324]
#  [0.53067637]
#  [0.52915029]
#  [0.54600241]
#  [0.5813258 ]
#  [0.57350989]
#  [0.54123682]
#  [0.54089336]
#  [0.52686021]
#  [0.5361852 ]
#  [0.554475  ]
#  [0.55820177]
#  [0.58261757]
#  [0.58393104]
#  [0.55921321]
#  [0.54906403]
#  [0.54745039]
#  [0.54779008]
#  [0.56672334]
#  [0.55803243]
#  [0.59125492]
#  [0.60861413]
#  [0.6238526 ]
#  [0.60263578]
#  [0.59779586]
#  [0.57708715]
#  [0.62129431]
#  [0.63354173]
#  [0.65500323]
#  [0.65296058]
#  [0.65105806]
#  [0.68110977]
#  [0.68604185]
#  [0.68011146]
#  [0.67887987]
#  [0.66471679]
#  [0.6986703 ]
#  [0.69162409]
#  [0.71677193]
#  [0.72437982]
#  [0.72198058]
#  [0.70650973]
#  [0.70907078]
#  [0.68459663]
#  [0.65414514]
#  [0.65411969]
#  [0.65884576]
#  [0.67839151]
#  [0.63157718]
#  [0.61990652]
#  [0.60724885]
#  [0.60095066]
#  [0.59802732]
#  [0.58351242]
#  [0.57542555]
#  [0.59866434]
#  [0.60527208]
#  [0.62881096]
#  [0.64330996]
#  [0.58376739]
#  [0.59186924]
#  [0.57612652]
#  [0.56634515]
#  [0.57449496]
#  [0.56414814]
#  [0.54487335]
#  [0.53044207]
#  [0.51172988]
#  [0.50561325]
#  [0.50811412]
#  [0.52901477]
#  [0.49945895]
#  [0.48422709]
#  [0.50679027]
#  [0.54075416]
#  [0.53814129]
#  [0.53105364]
#  [0.49145119]
#  [0.48107322]
#  [0.47016757]
#  [0.46931223]
#  [0.4911454 ]
#  [0.46030708]
#  [0.49365279]
#  [0.50274173]
#  [0.49409594]
#  [0.48791719]
#  [0.51095743]
#  [0.51969731]
#  [0.54289089]
#  [0.52142663]
#  [0.50464885]
#  [0.53379542]
#  [0.5230412 ]
#  [0.51388637]
#  [0.47944552]
#  [0.46233475]
#  [0.47478348]
#  [0.48318266]
#  [0.48804519]
#  [0.46329722]
#  [0.53489627]
#  [0.55457755]
#  [0.542618  ]
#  [0.55787816]
#  [0.5414363 ]
#  [0.53779508]
#  [0.53789854]
#  [0.52646217]
#  [0.54056598]
#  [0.55100129]
#  [0.54545387]
#  [0.52881345]
#  [0.52263002]
#  [0.56818923]
#  [0.56954882]
#  [0.56757766]
#  [0.54673159]
#  [0.52555704]
#  [0.52025614]
#  [0.53187131]
#  [0.5245908 ]
#  [0.53768032]
#  [0.54831877]
#  [0.54023475]
#  [0.50632929]
#  [0.49643876]
#  [0.48144305]
#  [0.48154467]
#  [0.49681135]
#  [0.47486535]
#  [0.47691084]
#  [0.46330292]
#  [0.45013622]
#  [0.47505068]]

# %%
prediction_dict3.keys()
# Out:
# dict_keys(['IXIC_lstm_1_day', 'IXIC_gru_1_day', 'IXIC_cnn_1_day', 'IXIC_xgb_1_day', 'IXIC_valid_data_1_day'])

# %%
prediction_list2 = []
prediction_list2 = ensemble_pipe(20, '20d', 'ensemble')
# prediction_list2
# Out:
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# 10/10 [==============================] - 3s 48ms/step
# IXIC_lstm_1_day DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 10/10 [==============================] - 2s 18ms/step
# IXIC_gru_1_day DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 10/10 [==============================] - 0s 3ms/step
# IXIC_cnn_1_day DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# IXIC_xgb_1_day DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 4s 44ms/step
# IXIC_lstm_5_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 3s 23ms/step
# IXIC_gru_5_days DONE
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# 10/10 [==============================] - 0s 3ms/step
# IXIC_cnn_5_days DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# IXIC_xgb_5_days DONE
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# 10/10 [==============================] - 3s 30ms/step
# IXIC_lstm_10_days DONE
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# 10/10 [==============================] - 1s 17ms/step
# IXIC_gru_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 0s 2ms/step
# IXIC_cnn_10_days DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# IXIC_xgb_10_days DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 29ms/step
# IXIC_lstm_1_month DONE
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# 10/10 [==============================] - 2s 18ms/step
# IXIC_gru_1_month DONE
# Restoring model weights from the end of the best epoch: 13.
# Epoch 18: early stopping
# 10/10 [==============================] - 0s 3ms/step
# IXIC_cnn_1_month DONE
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\ML\kaggle\kaggle_competition\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# IXIC_xgb_1_month DONE
